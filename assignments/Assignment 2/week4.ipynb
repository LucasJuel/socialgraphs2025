# %%
import networkx as nx
import matplotlib.pyplot as plt
import re
import os
import glob

# %% [markdown]
# ##Part 1

# %%
import urllib.request
response = urllib.request.urlopen('http://www.example.com/')
html = response.read()

print(html)
# Out:
# b'<!doctype html><html lang="en"><head><title>Example Domain</title><meta name="viewport" content="width=device-width, initial-scale=1"><style>body{background:#eee;width:60vw;margin:15vh auto;font-family:system-ui,sans-serif}h1{font-size:1.5em}div{opacity:0.8}a:link,a:visited{color:#348}</style><body><div><h1>Example Domain</h1><p>This domain is for use in documentation examples without needing permission. Avoid use in operations.<p><a href="https://iana.org/domains/example">Learn more</a></div></body></html>\n'

# %%
import pickle
import csv
from statistics import mean


with open('Cleaned_Rock_Musicians.txt', 'r', encoding='utf-8') as g:
    allArtists_text = g.read()


# Get all txt files in the wiki_pages directory
wiki_files = glob.glob('wiki_pages/*.txt')
print(f"Found {len(wiki_files)} txt files in wiki_pages directory")


def load_labmt_lexicon(filename='Data_Set_S1.txt'):
    """
    Loads the labMT (S1) dataset (tab-separated) and returns {word: happiness_average(float)}.
    Lines with '--' are skipped. Header must include 'word' and 'happiness_average'.
    """
    lex = {}
    with open(filename, encoding='utf-8') as f:
        reader = csv.DictReader(f, delimiter='\t')
        for row in reader:
            w = (row.get('word') or '').strip().lower()
            v = (row.get('happiness_average') or '').strip()
            if not w or v in ('', '--'):
                continue
            try:
                lex[w] = float(v)
            except ValueError:
                pass
    return lex

# precompile a plain-word tokenizer (letters only, case-insensitive)
_TOKEN_RE = re.compile(r"[A-Za-z]+")

# --- 2) Compute average happiness for a page's text ---
def page_happiness_average(text, lexicon):
    """
    Returns (avg_happiness, matched_count, token_count).
    Only words found in lexicon contribute to the average.
    """
    if not text:
        return (None, 0, 0)
    tokens = _TOKEN_RE.findall(text.lower())
    token_count = len(tokens)
    if token_count == 0:
        return (None, 0, 0)
    vals = [lexicon[t] for t in tokens if t in lexicon]
    if not vals:
        return (None, 0, token_count)
    return (mean(vals), len(vals), token_count)


artist_set = set()
for line in allArtists_text.strip().split('\n'):
    artist_name = line.strip()
    if artist_name:  # Skip empty lines
        artist_set.add(artist_name)

# Initialize lists to store all results
lexicon = load_labmt_lexicon("Data_Set_S1.txt")
file_results = {}

G = nx.DiGraph()

# Regular expression to match Wikipedia links
wiki_link_pattern = r'\[\[([^\[\]|]+)(?:\|[^\[\]]+)?\]\]'

# Process each file
for file_path in wiki_files:
    try:
        #print(f"\nProcessing file: {file_path}")

        artist_name = os.path.basename(file_path).replace('.txt', '')
        artist_name = artist_name.replace('_', ' ').strip()

        if artist_name not in artist_set:
            print(f"Skipping {artist_name} - not in original artist list")
            continue

        print(f"Artist name from filename: {artist_name}")
        # Read the file
        with open(file_path, 'r', encoding='utf-8') as f:
            text = f.read()
        
        # Extract all matches
        matches = re.findall(wiki_link_pattern, text)
        
        # Get unique links for this file
        unique_links = list(set(matches))
        
        # Check which links are found in the allArtists_text list
        found_in_artists = []

        # First remove common wiki markup
        clean_text = text
        clean_text = re.sub(r'\[\[.*?\]\]', ' ', clean_text)  # Remove links
        clean_text = re.sub(r'\{\{.*?\}\}', ' ', clean_text)  # Remove templates
        clean_text = re.sub(r'<.*?>', ' ', clean_text)  # Remove HTML tags
        clean_text = re.sub(r'==.*?==', ' ', clean_text)  # Remove headers
        clean_text = re.sub(r'\|.*?\|', ' ', clean_text)  # Remove table markup

        # Now count actual words (sequences of word characters)
        words = re.findall(r'\b\w+\b', clean_text.lower())

        word_count = len(words)
        avg, total, matched = page_happiness_average(clean_text, lexicon)

        if( artist_name not in G.nodes()):
            G.add_node(artist_name, word_count=word_count, happiness_average=avg)
            print(f" Is it this one Added node: {artist_name} with word count {word_count} and happiness average {avg}")
        else:
            G.nodes[artist_name]['word_count'] = word_count
            G.nodes[artist_name]['happiness_average'] = avg
        
        for link in unique_links:
            if link not in artist_set:
                continue  # Skip links not containing artists
            link_normalised = link.replace('_', ' ').strip()

            if link_normalised == artist_name:
                continue  # Skip self-loops

            if link_normalised not in G.nodes():
                G.add_node(link_normalised, word_count=0, happiness_average=avg)  # Add node with zero word count if not present
                print(f"  Added node: {link_normalised} with word count 0 and happiness average {avg}")

            if link_normalised in artist_set:
                G.add_edge(artist_name, link_normalised)
                #print(f"  Found link to artist: {link_normalised}")
                found_in_artists.append(link_normalised)

        
        # Print results for this file
        #print(f"\n{artist_name}:")
        #print(f"  Found edges: {len(found_in_artists)}")


        #with open('rock_network.pkl', 'wb') as f:
         #   pickle.dump(G, f)

    
    
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
# Out:
# Found 489 txt files in wiki_pages directory
# Artist name from filename: Funkadelic
#  Is it this one Added node: Funkadelic with word count 1663 and happiness average 5.485923190546528
#   Added node: Parliament-Funkadelic with word count 0 and happiness average 5.485923190546528
#   Added node: Sly and the Family Stone with word count 0 and happiness average 5.485923190546528
#   Added node: Jimi Hendrix with word count 0 and happiness average 5.485923190546528
#   Added node: Cream (band) with word count 0 and happiness average 5.485923190546528
#   Added node: Parliament (band) with word count 0 and happiness average 5.485923190546528
# Artist name from filename: Slayer
#  Is it this one Added node: Slayer with word count 9328 and happiness average 5.4417273070628225
#   Added node: Ted Nugent with word count 0 and happiness average 5.4417273070628225
#   Added node: Metallica with word count 0 and happiness average 5.4417273070628225
#   Added node: Megadeth with word count 0 and happiness average 5.4417273070628225
#   Added node: Aerosmith with word count 0 and happiness average 5.4417273070628225
#   Added node: Scorpions (band) with word count 0 and happiness average 5.4417273070628225
#   Added node: Van Halen with word count 0 and happiness average 5.4417273070628225
#   Added node: Trivium (band) with word count 0 and happiness average 5.4417273070628225
#   Added node: Sepultura with word count 0 and happiness average 5.4417273070628225
#   Added node: Black Sabbath with word count 0 and happiness average 5.4417273070628225
#   Added node: Rainbow (rock band) with word count 0 and happiness average 5.4417273070628225
#   Added node: Avenged Sevenfold with word count 0 and happiness average 5.4417273070628225
#   Added node: Pantera with word count 0 and happiness average 5.4417273070628225
#   Added node: Anthrax (American band) with word count 0 and happiness average 5.4417273070628225
#   Added node: Ozzy Osbourne with word count 0 and happiness average 5.4417273070628225
#   Added node: Kiss (band) with word count 0 and happiness average 5.4417273070628225
#   Added node: System of a Down with word count 0 and happiness average 5.4417273070628225
#   Added node: Deep Purple with word count 0 and happiness average 5.4417273070628225
#   Added node: Rush (band) with word count 0 and happiness average 5.4417273070628225
#   Added node: Lacuna Coil with word count 0 and happiness average 5.4417273070628225
#   Added node: Judas Priest with word count 0 and happiness average 5.4417273070628225
#   Added node: Killswitch Engage with word count 0 and happiness average 5.4417273070628225
#   Added node: Primus (band) with word count 0 and happiness average 5.4417273070628225
#   Added node: Motörhead with word count 0 and happiness average 5.4417273070628225
#   Added node: Accept (band) with word count 0 and happiness average 5.4417273070628225
#   Added node: Tool (band) with word count 0 and happiness average 5.4417273070628225
#   Added node: Lamb of God (band) with word count 0 and happiness average 5.4417273070628225
#   Added node: Slipknot (band) with word count 0 and happiness average 5.4417273070628225
#   Added node: W.A.S.P. (band) with word count 0 and happiness average 5.4417273070628225
#   Added node: Alice in Chains with word count 0 and happiness average 5.4417273070628225
#   Added node: Marilyn Manson (band) with word count 0 and happiness average 5.4417273070628225
#   Added node: Led Zeppelin with word count 0 and happiness average 5.4417273070628225
#   Added node: Bullet for My Valentine with word count 0 and happiness average 5.4417273070628225
#   Added node: Volbeat with word count 0 and happiness average 5.4417273070628225
#   Added node: Iron Maiden with word count 0 and happiness average 5.4417273070628225
# Artist name from filename: Ted Nugent
#   Added node: Ramones with word count 0 and happiness average 5.409209183673469
#   Added node: Frank Zappa with word count 0 and happiness average 5.409209183673469
#   Added node: Bo Diddley with word count 0 and happiness average 5.409209183673469
#   Added node: Kid Rock with word count 0 and happiness average 5.409209183673469
#   Added node: Meat Loaf with word count 0 and happiness average 5.409209183673469
#   Added node: Mitch Ryder with word count 0 and happiness average 5.409209183673469
#   Added node: Damn Yankees (band) with word count 0 and happiness average 5.409209183673469
#   Added node: Skid Row (American band) with word count 0 and happiness average 5.409209183673469
#   Added node: Foreigner (band) with word count 0 and happiness average 5.409209183673469
#   Added node: Paul McCartney with word count 0 and happiness average 5.409209183673469
#   Added node: Little Richard with word count 0 and happiness average 5.409209183673469
#   Added node: Styx (band) with word count 0 and happiness average 5.409209183673469
#   Added node: Nickelback with word count 0 and happiness average 5.409209183673469
#   Added node: Chuck Berry with word count 0 and happiness average 5.409209183673469
#   Added node: Stone Temple Pilots with word count 0 and happiness average 5.409209183673469
#   Added node: Pearl Jam with word count 0 and happiness average 5.409209183673469
# Artist name from filename: Great White
#  Is it this one Added node: Great White with word count 4223 and happiness average 5.5387569060773485
#   Added node: Mötley Crüe with word count 0 and happiness average 5.5387569060773485
#   Added node: Bon Jovi with word count 0 and happiness average 5.5387569060773485
#   Added node: Twisted Sister with word count 0 and happiness average 5.5387569060773485
#   Added node: Whitesnake with word count 0 and happiness average 5.5387569060773485
#   Added node: Warrant (American band) with word count 0 and happiness average 5.5387569060773485
#   Added node: Guns N' Roses with word count 0 and happiness average 5.5387569060773485
#   Added node: Tesla (band) with word count 0 and happiness average 5.5387569060773485
#   Added node: Ratt with word count 0 and happiness average 5.5387569060773485
#   Added node: Quiet Riot with word count 0 and happiness average 5.5387569060773485
#   Added node: Alice Cooper with word count 0 and happiness average 5.5387569060773485
#   Added node: Poison (American band) with word count 0 and happiness average 5.5387569060773485
# Artist name from filename: Days of the New
#  Is it this one Added node: Days of the New with word count 3201 and happiness average 5.5701182893539585
#   Added node: Dave Matthews Band with word count 0 and happiness average 5.5701182893539585
#   Added node: Finger Eleven with word count 0 and happiness average 5.5701182893539585
#   Added node: 3 Doors Down with word count 0 and happiness average 5.5701182893539585
#   Added node: Creed (band) with word count 0 and happiness average 5.5701182893539585
#   Added node: Train (band) with word count 0 and happiness average 5.5701182893539585
#   Added node: Velvet Revolver with word count 0 and happiness average 5.5701182893539585
# Artist name from filename: The Dave Clark Five
#  Is it this one Added node: The Dave Clark Five with word count 2311 and happiness average 5.517100694444444
#   Added node: John Mellencamp with word count 0 and happiness average 5.517100694444444
#   Added node: John Fogerty with word count 0 and happiness average 5.517100694444444
#   Added node: Billy Joel with word count 0 and happiness average 5.517100694444444
#   Added node: Joan Jett with word count 0 and happiness average 5.517100694444444
#   Added node: Manfred Mann with word count 0 and happiness average 5.517100694444444
#   Added node: Elton John with word count 0 and happiness average 5.517100694444444
# Artist name from filename: Keane (band)
#  Is it this one Added node: Keane (band) with word count 5282 and happiness average 5.567821020741086
#   Added node: U2 with word count 0 and happiness average 5.567821020741086
#   Added node: Fall Out Boy with word count 0 and happiness average 5.567821020741086
#   Added node: Coldplay with word count 0 and happiness average 5.567821020741086
#   Added node: Jeff Buckley with word count 0 and happiness average 5.567821020741086
#   Added node: Depeche Mode with word count 0 and happiness average 5.567821020741086
#   Added node: Genesis (band) with word count 0 and happiness average 5.567821020741086
#   Added node: Queen (band) with word count 0 and happiness average 5.567821020741086
# Artist name from filename: Jimmy Eat World
#  Is it this one Added node: Jimmy Eat World with word count 3471 and happiness average 5.583120567375887
#   Added node: Nirvana (band) with word count 0 and happiness average 5.583120567375887
#   Added node: Nine Inch Nails with word count 0 and happiness average 5.583120567375887
#   Added node: Green Day with word count 0 and happiness average 5.583120567375887
#   Added node: Radiohead with word count 0 and happiness average 5.583120567375887
#   Added node: Foo Fighters with word count 0 and happiness average 5.583120567375887
#   Added node: My Chemical Romance with word count 0 and happiness average 5.583120567375887
#   Added node: Beastie Boys with word count 0 and happiness average 5.583120567375887
#   Added node: The Smashing Pumpkins with word count 0 and happiness average 5.583120567375887
#   Added node: Pixies (band) with word count 0 and happiness average 5.583120567375887
#   Added node: Garbage (band) with word count 0 and happiness average 5.583120567375887
# Artist name from filename: Flogging Molly
#  Is it this one Added node: Flogging Molly with word count 1396 and happiness average 5.523671668137688
#   Added node: The All-American Rejects with word count 0 and happiness average 5.523671668137688
#   Added node: Weezer with word count 0 and happiness average 5.523671668137688
#   Added node: Dropkick Murphys with word count 0 and happiness average 5.523671668137688
#   Added node: The Offspring with word count 0 and happiness average 5.523671668137688
#   Added node: Asia (band) with word count 0 and happiness average 5.523671668137688
#   Added node: Social Distortion with word count 0 and happiness average 5.523671668137688
#   Added node: The Clash with word count 0 and happiness average 5.523671668137688
# Artist name from filename: Simple Plan
#  Is it this one Added node: Simple Plan with word count 4152 and happiness average 5.643061654135338
#   Added node: Blink-182 with word count 0 and happiness average 5.643061654135338
#   Added node: Sum 41 with word count 0 and happiness average 5.643061654135338
#   Added node: Cheap Trick with word count 0 and happiness average 5.643061654135338
#   Added node: Bowling for Soup with word count 0 and happiness average 5.643061654135338
#   Added node: Boys Like Girls with word count 0 and happiness average 5.643061654135338
#   Added node: Avril Lavigne with word count 0 and happiness average 5.643061654135338
#   Added node: Good Charlotte with word count 0 and happiness average 5.643061654135338
#   Added node: Black Veil Brides with word count 0 and happiness average 5.643061654135338
# Skipping AC DC - not in original artist list
# Artist name from filename: Foreigner (band)
#   Added node: Bad Company with word count 0 and happiness average 5.4890439367311075
#   Added node: Europe (band) with word count 0 and happiness average 5.4890439367311075
#   Added node: Peter Frampton with word count 0 and happiness average 5.4890439367311075
#   Added node: Phil Collins with word count 0 and happiness average 5.4890439367311075
#   Added node: Def Leppard with word count 0 and happiness average 5.4890439367311075
#   Added node: AC/DC with word count 0 and happiness average 5.4890439367311075
#   Added node: Eagles (band) with word count 0 and happiness average 5.4890439367311075
#   Added node: Heart (band) with word count 0 and happiness average 5.4890439367311075
#   Added node: Journey (band) with word count 0 and happiness average 5.4890439367311075
#   Added node: Rod Stewart with word count 0 and happiness average 5.4890439367311075
#   Added node: Steve Miller Band with word count 0 and happiness average 5.4890439367311075
#   Added node: Kansas (band) with word count 0 and happiness average 5.4890439367311075
# Artist name from filename: Steppenwolf (band)
#  Is it this one Added node: Steppenwolf (band) with word count 2119 and happiness average 5.471690962099125
#   Added node: Eddie Cochran with word count 0 and happiness average 5.471690962099125
#   Added node: Three Dog Night with word count 0 and happiness average 5.471690962099125
# Artist name from filename: Joe Walsh
#  Is it this one Added node: Joe Walsh with word count 5801 and happiness average 5.483363618408059
#   Added node: Survivor (band) with word count 0 and happiness average 5.483363618408059
#   Added node: Steve Winwood with word count 0 and happiness average 5.483363618408059
#   Added node: Bruce Springsteen with word count 0 and happiness average 5.483363618408059
#   Added node: Don Henley with word count 0 and happiness average 5.483363618408059
#   Added node: Ringo Starr with word count 0 and happiness average 5.483363618408059
#   Added node: George Thorogood with word count 0 and happiness average 5.483363618408059
#   Added node: Faces (band) with word count 0 and happiness average 5.483363618408059
#   Added node: Eric Clapton with word count 0 and happiness average 5.483363618408059
#   Added node: America (band) with word count 0 and happiness average 5.483363618408059
#   Added node: REO Speedwagon with word count 0 and happiness average 5.483363618408059
#   Added node: Glenn Frey with word count 0 and happiness average 5.483363618408059
#   Added node: Dan Fogelberg with word count 0 and happiness average 5.483363618408059
#   Added node: Fleetwood Mac with word count 0 and happiness average 5.483363618408059
#   Added node: Roy Orbison with word count 0 and happiness average 5.483363618408059
#   Added node: Emerson, Lake & Palmer with word count 0 and happiness average 5.483363618408059
#   Added node: Stevie Nicks with word count 0 and happiness average 5.483363618408059
# Artist name from filename: Hoobastank
#  Is it this one Added node: Hoobastank with word count 1968 and happiness average 5.55374025974026
#   Added node: Faith No More with word count 0 and happiness average 5.55374025974026
#   Added node: Incubus (band) with word count 0 and happiness average 5.55374025974026
#   Added node: Linkin Park with word count 0 and happiness average 5.55374025974026
# Artist name from filename: Eddie Money
#  Is it this one Added node: Eddie Money with word count 1393 and happiness average 5.5443150123051685
#   Added node: Kenny Loggins with word count 0 and happiness average 5.5443150123051685
#   Added node: Santana (band) with word count 0 and happiness average 5.5443150123051685
#   Added node: David Bowie with word count 0 and happiness average 5.5443150123051685
#   Added node: Van Morrison with word count 0 and happiness average 5.5443150123051685
# Artist name from filename: Guns N' Roses
#   Added node: Cinderella (band) with word count 0 and happiness average 5.445759450171821
#   Added node: Buckcherry with word count 0 and happiness average 5.445759450171821
#   Added node: New York Dolls with word count 0 and happiness average 5.445759450171821
#   Added node: Jim Croce with word count 0 and happiness average 5.445759450171821
#   Added node: Tom Petty with word count 0 and happiness average 5.445759450171821
#   Added node: Electric Light Orchestra with word count 0 and happiness average 5.445759450171821
#   Added node: Oasis (band) with word count 0 and happiness average 5.445759450171821
#   Added node: John Lennon with word count 0 and happiness average 5.445759450171821
#   Added node: The Rolling Stones with word count 0 and happiness average 5.445759450171821
#   Added node: Alter Bridge with word count 0 and happiness average 5.445759450171821
#   Added node: Sex Pistols with word count 0 and happiness average 5.445759450171821
#   Added node: Soundgarden with word count 0 and happiness average 5.445759450171821
#   Added node: Hinder with word count 0 and happiness average 5.445759450171821
#   Added node: Red Hot Chili Peppers with word count 0 and happiness average 5.445759450171821
#   Added node: T. Rex (band) with word count 0 and happiness average 5.445759450171821
#   Added node: The Cult with word count 0 and happiness average 5.445759450171821
#   Added node: Neil Young with word count 0 and happiness average 5.445759450171821
#   Added node: Jane's Addiction with word count 0 and happiness average 5.445759450171821
#   Added node: Paul McCartney and Wings with word count 0 and happiness average 5.445759450171821
#   Added node: Joe Satriani with word count 0 and happiness average 5.445759450171821
#   Added node: Beck with word count 0 and happiness average 5.445759450171821
# Artist name from filename: Roxy Music
#  Is it this one Added node: Roxy Music with word count 4622 and happiness average 5.566330916623511
#   Added node: Pink Floyd with word count 0 and happiness average 5.566330916623511
#   Added node: Franz Ferdinand (band) with word count 0 and happiness average 5.566330916623511
#   Added node: Bob Dylan with word count 0 and happiness average 5.566330916623511
#   Added node: Duran Duran with word count 0 and happiness average 5.566330916623511
#   Added node: The Velvet Underground with word count 0 and happiness average 5.566330916623511
#   Added node: Bryan Ferry with word count 0 and happiness average 5.566330916623511
#   Added node: Echo & the Bunnymen with word count 0 and happiness average 5.566330916623511
#   Added node: Elvis Presley with word count 0 and happiness average 5.566330916623511
#   Added node: Talking Heads with word count 0 and happiness average 5.566330916623511
#   Added node: Simple Minds with word count 0 and happiness average 5.566330916623511
# Artist name from filename: Limp Bizkit
#  Is it this one Added node: Limp Bizkit with word count 10759 and happiness average 5.473133272478321
#   Added node: R.E.M. with word count 0 and happiness average 5.473133272478321
#   Added node: Staind with word count 0 and happiness average 5.473133272478321
#   Added node: Rage Against the Machine with word count 0 and happiness average 5.473133272478321
#   Added node: Alanis Morissette with word count 0 and happiness average 5.473133272478321
#   Added node: Korn with word count 0 and happiness average 5.473133272478321
#   Added node: Run-DMC with word count 0 and happiness average 5.473133272478321
#   Added node: White Zombie (band) with word count 0 and happiness average 5.473133272478321
#   Added node: Deftones with word count 0 and happiness average 5.473133272478321
#   Added node: Marilyn Manson with word count 0 and happiness average 5.473133272478321
#   Added node: Chevelle (band) with word count 0 and happiness average 5.473133272478321
#   Added node: Filter (band) with word count 0 and happiness average 5.473133272478321
#   Added node: P.O.D. with word count 0 and happiness average 5.473133272478321
#   Added node: The Who with word count 0 and happiness average 5.473133272478321
# Artist name from filename: Midnight Oil
#  Is it this one Added node: Midnight Oil with word count 8135 and happiness average 5.566652106084243
#   Added node: Kings of Leon with word count 0 and happiness average 5.566652106084243
#   Added node: Cold Chisel with word count 0 and happiness average 5.566652106084243
#   Added node: Yes (band) with word count 0 and happiness average 5.566652106084243
#   Added node: The Tragically Hip with word count 0 and happiness average 5.566652106084243
#   Added node: The Killers with word count 0 and happiness average 5.566652106084243
#   Added node: The Jam with word count 0 and happiness average 5.566652106084243
#   Added node: Silverchair with word count 0 and happiness average 5.566652106084243
#   Added node: The Cranberries with word count 0 and happiness average 5.566652106084243
#   Added node: Creedence Clearwater Revival with word count 0 and happiness average 5.566652106084243
#   Added node: INXS with word count 0 and happiness average 5.566652106084243
#   Added node: Peter Gabriel with word count 0 and happiness average 5.566652106084243
#   Added node: Jethro Tull (band) with word count 0 and happiness average 5.566652106084243
#   Added node: Imagine Dragons with word count 0 and happiness average 5.566652106084243
#   Added node: Crowded House with word count 0 and happiness average 5.566652106084243
# Artist name from filename: Awolnation
#  Is it this one Added node: Awolnation with word count 3473 and happiness average 5.590092936802974
#   Added node: Twenty One Pilots with word count 0 and happiness average 5.590092936802974
#   Added node: 311 (band) with word count 0 and happiness average 5.590092936802974
#   Added node: Goo Goo Dolls with word count 0 and happiness average 5.590092936802974
#   Added node: The Cars with word count 0 and happiness average 5.590092936802974
#   Added node: Rise Against with word count 0 and happiness average 5.590092936802974
# Artist name from filename: Dio (band)
#  Is it this one Added node: Dio (band) with word count 2243 and happiness average 5.450394088669951
#   Added node: Blue Öyster Cult with word count 0 and happiness average 5.450394088669951
#   Added node: Tenacious D with word count 0 and happiness average 5.450394088669951
# Artist name from filename: Marilyn Manson
#   Added node: Disturbed (band) with word count 0 and happiness average 5.366297434526991
#   Added node: Five Finger Death Punch with word count 0 and happiness average 5.366297434526991
#   Added node: Hole (band) with word count 0 and happiness average 5.366297434526991
#   Added node: Rammstein with word count 0 and happiness average 5.366297434526991
#   Added node: Mudvayne with word count 0 and happiness average 5.366297434526991
# Artist name from filename: Thirty Seconds to Mars
#  Is it this one Added node: Thirty Seconds to Mars with word count 3836 and happiness average 5.5246176470588235
#   Added node: Muse (band) with word count 0 and happiness average 5.5246176470588235
#   Added node: Audioslave with word count 0 and happiness average 5.5246176470588235
#   Added node: The Used with word count 0 and happiness average 5.5246176470588235
#   Added node: Our Lady Peace with word count 0 and happiness average 5.5246176470588235
#   Added node: Puddle of Mudd with word count 0 and happiness average 5.5246176470588235
#   Added node: The Cure with word count 0 and happiness average 5.5246176470588235
#   Added node: Chris Cornell with word count 0 and happiness average 5.5246176470588235
#   Added node: Billy Talent with word count 0 and happiness average 5.5246176470588235
# Artist name from filename: Black Stone Cherry
#  Is it this one Added node: Black Stone Cherry with word count 1233 and happiness average 5.627521126760564
#   Added node: Highly Suspect with word count 0 and happiness average 5.627521126760564
#   Added node: Tracy Chapman with word count 0 and happiness average 5.627521126760564
#   Added node: Shinedown with word count 0 and happiness average 5.627521126760564
#   Added node: Theory of a Deadman with word count 0 and happiness average 5.627521126760564
#   Added node: Lynyrd Skynyrd with word count 0 and happiness average 5.627521126760564
#   Added node: Halestorm with word count 0 and happiness average 5.627521126760564
# Artist name from filename: Herman's Hermits
#  Is it this one Added node: Herman's Hermits with word count 3987 and happiness average 5.553081873435824
#   Added node: The Beatles with word count 0 and happiness average 5.553081873435824
#   Added node: Morrissey with word count 0 and happiness average 5.553081873435824
# Artist name from filename: Dr. Hook & the Medicine Show
#  Is it this one Added node: Dr. Hook & the Medicine Show with word count 4 and happiness average 5.575
# Artist name from filename: Manfred Mann's Earth Band
#  Is it this one Added node: Manfred Mann's Earth Band with word count 4220 and happiness average 5.555889925973608
#   Added node: Manfred Mann (musician) with word count 0 and happiness average 5.555889925973608
#   Added node: The Police with word count 0 and happiness average 5.555889925973608
#   Added node: Icehouse (band) with word count 0 and happiness average 5.555889925973608
#   Added node: Manfred Mann Chapter Three with word count 0 and happiness average 5.555889925973608
#   Added node: The Lovin' Spoonful with word count 0 and happiness average 5.555889925973608
# Artist name from filename: The Pretenders
#  Is it this one Added node: The Pretenders with word count 2124 and happiness average 5.497026086956522
# Artist name from filename: Ghost (Swedish band)
#  Is it this one Added node: Ghost (Swedish band) with word count 7434 and happiness average 5.4941195232499584
#   Added node: ABBA with word count 0 and happiness average 5.4941195232499584
# Artist name from filename: 10cc
#  Is it this one Added node: 10cc with word count 6551 and happiness average 5.47658865248227
#   Added node: The Hollies with word count 0 and happiness average 5.47658865248227
#   Added node: Simon & Garfunkel with word count 0 and happiness average 5.47658865248227
#   Added node: Toto (band) with word count 0 and happiness average 5.47658865248227
#   Added node: The Yardbirds with word count 0 and happiness average 5.47658865248227
#   Added node: Steely Dan with word count 0 and happiness average 5.47658865248227
#   Added node: George Harrison with word count 0 and happiness average 5.47658865248227
# Artist name from filename: Eric Clapton
#   Added node: The Band with word count 0 and happiness average 5.495767150583547
#   Added node: Sting (musician) with word count 0 and happiness average 5.495767150583547
#   Added node: Tom Petty and the Heartbreakers with word count 0 and happiness average 5.495767150583547
#   Added node: Bee Gees with word count 0 and happiness average 5.495767150583547
#   Added node: Buddy Holly with word count 0 and happiness average 5.495767150583547
#   Added node: Traffic (band) with word count 0 and happiness average 5.495767150583547
#   Added node: Sheryl Crow with word count 0 and happiness average 5.495767150583547
#   Added node: John Mayer with word count 0 and happiness average 5.495767150583547
#   Added node: Dire Straits with word count 0 and happiness average 5.495767150583547
#   Added node: Stevie Ray Vaughan with word count 0 and happiness average 5.495767150583547
#   Added node: John Mayall & the Bluesbreakers with word count 0 and happiness average 5.495767150583547
# Artist name from filename: Kiss (band)
#   Added node: Thin Lizzy with word count 0 and happiness average 5.532890034997237
#   Added node: Slade with word count 0 and happiness average 5.532890034997237
#   Added node: Bob Seger with word count 0 and happiness average 5.532890034997237
# Artist name from filename: Pearl Jam
#   Added node: Grateful Dead with word count 0 and happiness average 5.530144872283644
# Artist name from filename: Billy Talent
#   Added node: Arcade Fire with word count 0 and happiness average 5.53836782376502
#   Added node: Paramore with word count 0 and happiness average 5.53836782376502
# Artist name from filename: Starset
#  Is it this one Added node: Starset with word count 2917 and happiness average 5.578172043010753
#   Added node: Seether with word count 0 and happiness average 5.578172043010753
#   Added node: Breaking Benjamin with word count 0 and happiness average 5.578172043010753
# Artist name from filename: Jack White
#  Is it this one Added node: Jack White with word count 10113 and happiness average 5.554781066536203
#   Added node: The White Stripes with word count 0 and happiness average 5.554781066536203
#   Added node: Queens of the Stone Age with word count 0 and happiness average 5.554781066536203
# Artist name from filename: Alanis Morissette
#   Added node: Matchbox Twenty with word count 0 and happiness average 5.589083317869735
#   Added node: Barenaked Ladies with word count 0 and happiness average 5.589083317869735
#   Added node: No Doubt with word count 0 and happiness average 5.589083317869735
# Artist name from filename: Korn
#   Added node: Flyleaf (band) with word count 0 and happiness average 5.511690235690236
#   Added node: Stone Sour with word count 0 and happiness average 5.511690235690236
#   Added node: Steve Vai with word count 0 and happiness average 5.511690235690236
#   Added node: Charlie Daniels with word count 0 and happiness average 5.511690235690236
#   Added node: 10 Years (band) with word count 0 and happiness average 5.511690235690236
#   Added node: Evanescence with word count 0 and happiness average 5.511690235690236
# Artist name from filename: The Marshall Tucker Band
#  Is it this one Added node: The Marshall Tucker Band with word count 4284 and happiness average 5.5751226790450925
#   Added node: The Allman Brothers Band with word count 0 and happiness average 5.5751226790450925
# Artist name from filename: Steve Vai
# Artist name from filename: George Thorogood
# Artist name from filename: Lamb of God (band)
#   Added node: Rob Zombie with word count 0 and happiness average 5.5239669421487605
# Artist name from filename: Peter Frampton
#   Added node: Jerry Lee Lewis with word count 0 and happiness average 5.52136257989541
#   Added node: Harry Nilsson with word count 0 and happiness average 5.52136257989541
#   Added node: Status Quo (band) with word count 0 and happiness average 5.52136257989541
#   Added node: Small Faces with word count 0 and happiness average 5.52136257989541
# Artist name from filename: Dire Straits
#   Added node: Bryan Adams with word count 0 and happiness average 5.522362568937911
# Artist name from filename: Linkin Park
#   Added node: Bring Me the Horizon with word count 0 and happiness average 5.5900973918785075
# Artist name from filename: The Moody Blues
#  Is it this one Added node: The Moody Blues with word count 8610 and happiness average 5.46806306918581
#   Added node: Robert Plant with word count 0 and happiness average 5.46806306918581
#   Added node: Donovan with word count 0 and happiness average 5.46806306918581
# Artist name from filename: Bill Haley & His Comets
#  Is it this one Added node: Bill Haley & His Comets with word count 6513 and happiness average 5.422426235669987
#   Added node: Chubby Checker with word count 0 and happiness average 5.422426235669987
# Artist name from filename: Black Sabbath
#   Added node: Boston (band) with word count 0 and happiness average 5.412613812059783
#   Added node: Sonic Youth with word count 0 and happiness average 5.412613812059783
#   Added node: Godsmack with word count 0 and happiness average 5.412613812059783
# Artist name from filename: Our Lady Peace
#   Added node: Bush (British band) with word count 0 and happiness average 5.60328132618235
#   Added node: A Perfect Circle with word count 0 and happiness average 5.60328132618235
#   Added node: Live (band) with word count 0 and happiness average 5.60328132618235
# Artist name from filename: Bloodhound Gang
#  Is it this one Added node: Bloodhound Gang with word count 2921 and happiness average 5.512556719022688
# Artist name from filename: Asia (band)
#   Added node: Uriah Heep (band) with word count 0 and happiness average 5.509526400644901
# Artist name from filename: John Mayall
#  Is it this one Added node: John Mayall with word count 3466 and happiness average 5.468610315186247
#   Added node: Canned Heat with word count 0 and happiness average 5.468610315186247
#   Added node: Chris Rea with word count 0 and happiness average 5.468610315186247
#   Added node: The Mothers of Invention with word count 0 and happiness average 5.468610315186247
# Artist name from filename: The Hollies
# Artist name from filename: Run-DMC
#   Added node: Third Eye Blind with word count 0 and happiness average 5.456895393474088
#   Added node: Harry Chapin with word count 0 and happiness average 5.456895393474088
# Artist name from filename: Steve Winwood
#   Added node: Joe Cocker with word count 0 and happiness average 5.548076392084676
#   Added node: Lou Reed with word count 0 and happiness average 5.548076392084676
# Artist name from filename: Kid Rock
#   Added node: ZZ Top with word count 0 and happiness average 5.58058025177026
#   Added node: 38 Special (band) with word count 0 and happiness average 5.58058025177026
# Artist name from filename: Styx (band)
# Artist name from filename: Small Faces
# Artist name from filename: Hootie & the Blowfish
#  Is it this one Added node: Hootie & the Blowfish with word count 1954 and happiness average 5.5780246113989636
# Artist name from filename: Boys Like Girls
#   Added node: Dashboard Confessional with word count 0 and happiness average 5.628710601719198
# Artist name from filename: Kansas (band)
# Artist name from filename: Shakin' Stevens
#  Is it this one Added node: Shakin' Stevens with word count 2332 and happiness average 5.486321218074656
# Artist name from filename: Cheap Trick
# Artist name from filename: Ozzy Osbourne
# Artist name from filename: Survivor (band)
# Artist name from filename: Cold Chisel
#   Added node: Little River Band with word count 0 and happiness average 5.509174492247215
# Artist name from filename: Chubby Checker
#   Added node: Fats Domino with word count 0 and happiness average 5.492448466566113
# Artist name from filename: New York Dolls
#   Added node: Billy Idol with word count 0 and happiness average 5.517559884180048
#   Added node: Blondie (band) with word count 0 and happiness average 5.517559884180048
# Artist name from filename: Elton John
#   Added node: Elvis Costello with word count 0 and happiness average 5.529465889104879
# Artist name from filename: Def Leppard
#   Added node: The Kinks with word count 0 and happiness average 5.515037661946369
#   Added node: Badfinger with word count 0 and happiness average 5.515037661946369
#   Added node: The Sweet with word count 0 and happiness average 5.515037661946369
#   Added node: Billy Squier with word count 0 and happiness average 5.515037661946369
# Artist name from filename: The Cure
#   Added node: AFI (band) with word count 0 and happiness average 5.540297792230019
#   Added node: Foals (band) with word count 0 and happiness average 5.540297792230019
#   Added node: Interpol (band) with word count 0 and happiness average 5.540297792230019
# Artist name from filename: Ringo Starr
#   Added node: Lenny Kravitz with word count 0 and happiness average 5.498064164648911
# Artist name from filename: Charlie Daniels
# Artist name from filename: Joan Jett
# Artist name from filename: Staind
#   Added node: James Taylor with word count 0 and happiness average 5.545678960603521
#   Added node: Three Days Grace with word count 0 and happiness average 5.545678960603521
# Artist name from filename: Snow Patrol
#  Is it this one Added node: Snow Patrol with word count 3117 and happiness average 5.525418552036199
# Artist name from filename: Talking Heads
#   Added node: Crash Test Dummies with word count 0 and happiness average 5.541826484018265
# Artist name from filename: Breaking Benjamin
#   Added node: Daughtry (band) with word count 0 and happiness average 5.485950940860215
#   Added node: Papa Roach with word count 0 and happiness average 5.485950940860215
#   Added node: Skillet (band) with word count 0 and happiness average 5.485950940860215
#   Added node: Thousand Foot Krutch with word count 0 and happiness average 5.485950940860215
# Artist name from filename: Dave Matthews Band
#   Added node: The Flaming Lips with word count 0 and happiness average 5.556010898158587
#   Added node: Blues Traveler with word count 0 and happiness average 5.556010898158587
#   Added node: Cage the Elephant with word count 0 and happiness average 5.556010898158587
# Artist name from filename: The Fray
#  Is it this one Added node: The Fray with word count 3857 and happiness average 5.5564884530211955
#   Added node: Counting Crows with word count 0 and happiness average 5.5564884530211955
# Artist name from filename: Theory of a Deadman
# Artist name from filename: Van Halen
#   Added node: Hall & Oates with word count 0 and happiness average 5.472851041110518
#   Added node: Extreme (band) with word count 0 and happiness average 5.472851041110518
# Artist name from filename: Harry Chapin
# Artist name from filename: Van Morrison
#   Added node: The Doors with word count 0 and happiness average 5.520420657276995
# Artist name from filename: Judas Priest
#   Added node: Queensrÿche with word count 0 and happiness average 5.4595923689267085
#   Added node: Janis Joplin with word count 0 and happiness average 5.4595923689267085
# Artist name from filename: Jefferson Starship
#  Is it this one Added node: Jefferson Starship with word count 3673 and happiness average 5.438611756891398
#   Added node: Ten Years After with word count 0 and happiness average 5.438611756891398
#   Added node: Jefferson Airplane with word count 0 and happiness average 5.438611756891398
#   Added node: Starship (band) with word count 0 and happiness average 5.438611756891398
# Artist name from filename: The Smashing Pumpkins
#   Added node: The Monkees with word count 0 and happiness average 5.509555522521183
#   Added node: Panic! at the Disco with word count 0 and happiness average 5.509555522521183
#   Added node: Joy Division with word count 0 and happiness average 5.509555522521183
# Artist name from filename: Harry Nilsson
# Artist name from filename: Bob Dylan
#   Added node: Traveling Wilburys with word count 0 and happiness average 5.487318865228927
#   Added node: The Byrds with word count 0 and happiness average 5.487318865228927
#   Added node: Duane Eddy with word count 0 and happiness average 5.487318865228927
# Artist name from filename: ZZ Top
# Artist name from filename: Highly Suspect
#   Added node: Sublime (band) with word count 0 and happiness average 5.558040712468193
#   Added node: Catfish and the Bottlemen with word count 0 and happiness average 5.558040712468193
# Artist name from filename: Skillet (band)
# Artist name from filename: Peter Gabriel
#   Added node: Vampire Weekend with word count 0 and happiness average 5.521367181960006
# Artist name from filename: Icehouse (band)
# Artist name from filename: Hole (band)
#   Added node: The Beach Boys with word count 0 and happiness average 5.537102333931777
# Artist name from filename: Tenacious D
# Artist name from filename: John Lennon
# Artist name from filename: Matchbox Twenty
# Artist name from filename: Sex Pistols
#   Added node: Iggy Pop with word count 0 and happiness average 5.406329961907264
# Artist name from filename: Avenged Sevenfold
#   Added node: James Blunt with word count 0 and happiness average 5.557630724846736
# Artist name from filename: Live (band)
#   Added node: Collective Soul with word count 0 and happiness average 5.582287555376561
#   Added node: Everclear (band) with word count 0 and happiness average 5.582287555376561
# Artist name from filename: 10 Years (band)
# Artist name from filename: Muse (band)
#   Added node: Kaiser Chiefs with word count 0 and happiness average 5.567720664589824
#   Added node: Arctic Monkeys with word count 0 and happiness average 5.567720664589824
# Artist name from filename: Adam Ant
#  Is it this one Added node: Adam Ant with word count 7069 and happiness average 5.546729946981358
#   Added node: Gene Vincent with word count 0 and happiness average 5.546729946981358
# Artist name from filename: Bullet for My Valentine
# Artist name from filename: Bee Gees
# Artist name from filename: Mudvayne
# Artist name from filename: Lifehouse (band)
#  Is it this one Added node: Lifehouse (band) with word count 2895 and happiness average 5.5883618046430135
# Artist name from filename: Deftones
# Artist name from filename: Manfred Mann Chapter Three
# Artist name from filename: Filter (band)
# Artist name from filename: Donovan
#   Added node: The Animals with word count 0 and happiness average 5.51715394038383
# Artist name from filename: Pixies (band)
#   Added node: Modest Mouse with word count 0 and happiness average 5.536876006441224
# Artist name from filename: The Fixx
#  Is it this one Added node: The Fixx with word count 1209 and happiness average 5.5320266120777895
# Artist name from filename: Van Zant (band)
#  Is it this one Added node: Van Zant (band) with word count 4 and happiness average 5.575
# Artist name from filename: The Big Bopper
#  Is it this one Added node: The Big Bopper with word count 2831 and happiness average 5.4318208702999575
#   Added node: Ritchie Valens with word count 0 and happiness average 5.4318208702999575
# Artist name from filename: Gary Glitter
#  Is it this one Added node: Gary Glitter with word count 4964 and happiness average 5.336306965761511
# Artist name from filename: The Four Seasons (band)
#  Is it this one Added node: The Four Seasons (band) with word count 8727 and happiness average 5.504128512788127
# Artist name from filename: P.O.D.
# Artist name from filename: Halestorm
# Artist name from filename: Tracy Chapman
# Artist name from filename: Anthrax (American band)
#   Added node: Living Colour with word count 0 and happiness average 5.467945267958951
# Artist name from filename: Dashboard Confessional
#   Added node: The Strokes with word count 0 and happiness average 5.610438356164384
#   Added node: The Hives with word count 0 and happiness average 5.610438356164384
# Artist name from filename: Grateful Dead
# Artist name from filename: The Who
#   Added node: Blur (band) with word count 0 and happiness average 5.457174532139951
# Artist name from filename: Fuel (band)
#  Is it this one Added node: Fuel (band) with word count 3748 and happiness average 5.547523264137437
#   Added node: Saliva (band) with word count 0 and happiness average 5.547523264137437
# Artist name from filename: Fun (band)
#  Is it this one Added node: Fun (band) with word count 1731 and happiness average 5.654882271468144
# Artist name from filename: Linda Ronstadt
#  Is it this one Added node: Linda Ronstadt with word count 12663 and happiness average 5.571855622397038
#   Added node: Jackson Browne with word count 0 and happiness average 5.571855622397038
#   Added node: Pat Benatar with word count 0 and happiness average 5.571855622397038
# Artist name from filename: Paul McCartney and Wings
# Artist name from filename: Bad Company
# Artist name from filename: Imagine Dragons
#   Added node: Foster the People with word count 0 and happiness average 5.604479216435738
#   Added node: X Ambassadors with word count 0 and happiness average 5.604479216435738
#   Added node: Mumford & Sons with word count 0 and happiness average 5.604479216435738
# Artist name from filename: Trivium (band)
#   Added node: Pop Evil with word count 0 and happiness average 5.508993593166044
# Artist name from filename: Counting Crows
# Artist name from filename: The Outfield
#  Is it this one Added node: The Outfield with word count 2560 and happiness average 5.496713747645951
# Artist name from filename: FireHouse
#  Is it this one Added node: FireHouse with word count 2210 and happiness average 5.555214484679666
# Artist name from filename: Bruce Springsteen
#   Added node: Melissa Etheridge with word count 0 and happiness average 5.527326462923478
# Artist name from filename: Coldplay
#   Added node: Travis (band) with word count 0 and happiness average 5.5466254834550925
# Artist name from filename: Genesis (band)
#   Added node: Mike and the Mechanics with word count 0 and happiness average 5.490084591498019
#   Added node: Crosby, Stills, Nash & Young with word count 0 and happiness average 5.490084591498019
# Artist name from filename: X Ambassadors
# Artist name from filename: Steve Miller Band
#   Added node: Chicago (band) with word count 0 and happiness average 5.554256495301272
# Artist name from filename: Alice Cooper
#   Added node: Edgar Winter with word count 0 and happiness average 5.492739158858139
#   Added node: Alice Cooper (band) with word count 0 and happiness average 5.492739158858139
# Artist name from filename: Good Charlotte
#   Added node: The Smiths with word count 0 and happiness average 5.575933946940985
# Artist name from filename: Rush (band)
#   Added node: Supertramp with word count 0 and happiness average 5.498074476697121
# Artist name from filename: Nine Inch Nails
# Artist name from filename: Tom Petty and the Heartbreakers
#   Added node: The Lumineers with word count 0 and happiness average 5.479941318605454
# Artist name from filename: Crosby, Stills, Nash & Young
# Artist name from filename: The Offspring
#   Added node: Sublime with Rome with word count 0 and happiness average 5.493383458646616
# Artist name from filename: Papa Roach
#   Added node: Saving Abel with word count 0 and happiness average 5.5880829539706625
# Artist name from filename: Robert Plant
# Artist name from filename: Evanescence
#   Added node: The Pretty Reckless with word count 0 and happiness average 5.496611409068747
# Artist name from filename: Florence and the Machine
#  Is it this one Added node: Florence and the Machine with word count 4749 and happiness average 5.567721062129415
# Artist name from filename: Everclear (band)
#   Added node: X (American band) with word count 0 and happiness average 5.506532374100719
#   Added node: Gin Blossoms with word count 0 and happiness average 5.506532374100719
# Artist name from filename: Aerosmith
#   Added node: The Black Crowes with word count 0 and happiness average 5.504238930336208
# Artist name from filename: Catfish and the Bottlemen
# Artist name from filename: Finger Eleven
# Artist name from filename: Ten Years After
# Artist name from filename: Traveling Wilburys
# Artist name from filename: Train (band)
#   Added node: The Script with word count 0 and happiness average 5.633504538939322
# Artist name from filename: Shinedown
# Artist name from filename: The Boxtones
#  Is it this one Added node: The Boxtones with word count 478 and happiness average 5.7411021505376345
# Artist name from filename: Iggy Pop
# Artist name from filename: Crowded House
#   Added node: Men at Work with word count 0 and happiness average 5.551798137236267
# Artist name from filename: Blur (band)
#   Added node: The Verve with word count 0 and happiness average 5.479345597897503
# Artist name from filename: The Doobie Brothers
#  Is it this one Added node: The Doobie Brothers with word count 6331 and happiness average 5.492420197330238
#   Added node: Air Supply with word count 0 and happiness average 5.492420197330238
#   Added node: Christopher Cross with word count 0 and happiness average 5.492420197330238
# Artist name from filename: Mike and the Mechanics
# Artist name from filename: John Mellencamp
# Artist name from filename: Whitesnake
# Artist name from filename: The Allman Brothers Band
# Artist name from filename: Primus (band)
#   Added node: Coheed and Cambria with word count 0 and happiness average 5.543196873071384
# Artist name from filename: Silverchair
# Artist name from filename: Montgomery Gentry
#  Is it this one Added node: Montgomery Gentry with word count 3612 and happiness average 5.482333333333333
#   Added node: Five for Fighting with word count 0 and happiness average 5.482333333333333
# Artist name from filename: Tommy James and the Shondells
#  Is it this one Added node: Tommy James and the Shondells with word count 1963 and happiness average 5.472401038286827
# Artist name from filename: Death Cab for Cutie
#  Is it this one Added node: Death Cab for Cutie with word count 4184 and happiness average 5.535990227076746
# Artist name from filename: Metallica
#   Added node: Greta Van Fleet with word count 0 and happiness average 5.490867433930094
# Artist name from filename: Simon & Garfunkel
# Artist name from filename: Gene Vincent
#   Added node: Ian Dury with word count 0 and happiness average 5.45577591757888
# Artist name from filename: Cinderella (band)
# Artist name from filename: Fall Out Boy
# Artist name from filename: Jane's Addiction
# Artist name from filename: Seether
# Artist name from filename: The Pretty Reckless
# Artist name from filename: The All-American Rejects
# Artist name from filename: Badfinger
# Artist name from filename: 38 Special (band)
#   Added node: Huey Lewis and the News with word count 0 and happiness average 5.561015730337079
# Artist name from filename: The Cardigans
#  Is it this one Added node: The Cardigans with word count 1967 and happiness average 5.642363076923077
# Artist name from filename: The J. Geils Band
#  Is it this one Added node: The J. Geils Band with word count 3283 and happiness average 5.50867775138559
# Artist name from filename: George Harrison
# Artist name from filename: Huey Lewis and the News
# Artist name from filename: Thin Lizzy
#   Added node: Bachman–Turner Overdrive with word count 0 and happiness average 5.4343713990249665
# Artist name from filename: Rise Against
# Artist name from filename: Steely Dan
# Artist name from filename: America (band)
#   Added node: The Mamas & the Papas with word count 0 and happiness average 5.535860973187686
# Artist name from filename: Edgar Winter
# Artist name from filename: Ramones
#   Added node: The Jesus and Mary Chain with word count 0 and happiness average 5.4664586980741685
# Artist name from filename: R.E.M.
# Artist name from filename: Lacuna Coil
# Artist name from filename: Gin Blossoms
# Artist name from filename: Pantera
# Artist name from filename: Everlast
#  Is it this one Added node: Everlast with word count 1955 and happiness average 5.46749248346362
# Artist name from filename: U2
# Artist name from filename: Dan Fogelberg
# Artist name from filename: Chevelle (band)
# Artist name from filename: AFI (band)
# Artist name from filename: Pat Benatar
#   Added node: The Bangles with word count 0 and happiness average 5.568875453446191
#   Added node: Loverboy with word count 0 and happiness average 5.568875453446191
# Artist name from filename: X (American band)
# Artist name from filename: Buddy Holly
#   Added node: The Everly Brothers with word count 0 and happiness average 5.483797209935352
# Artist name from filename: Slade
# Artist name from filename: Arcade Fire
# Artist name from filename: Stevie Ray Vaughan
# Artist name from filename: T. Rex (band)
#   Added node: Smokie (band) with word count 0 and happiness average 5.516036585365853
# Artist name from filename: Kings of Leon
# Skipping AllMusic - not in original artist list
# Artist name from filename: Heart (band)
# Artist name from filename: Nirvana (band)
# Artist name from filename: Little Richard
# Artist name from filename: Rob Zombie
# Artist name from filename: Dallas Green (musician)
#  Is it this one Added node: Dallas Green (musician) with word count 1 and happiness average None
# Artist name from filename: The Beach Boys
#   Added node: Grand Funk Railroad with word count 0 and happiness average 5.551700590068289
# Artist name from filename: Jefferson Airplane
# Artist name from filename: The Bangles
# Artist name from filename: System of a Down
# Artist name from filename: Sixto Rodriguez
#  Is it this one Added node: Sixto Rodriguez with word count 3014 and happiness average 5.518379131819992
# Artist name from filename: Michael Martin Murphey
#  Is it this one Added node: Michael Martin Murphey with word count 4016 and happiness average 5.659783299624386
# Artist name from filename: Blue October
#  Is it this one Added node: Blue October with word count 4336 and happiness average 5.576570283423991
# Artist name from filename: The Cult
# Artist name from filename: The Flaming Lips
#   Added node: Cake (band) with word count 0 and happiness average 5.532328974796286
# Artist name from filename: Creed (band)
# Artist name from filename: Crash Test Dummies
# Artist name from filename: The Lumineers
# Skipping Queensryche - not in original artist list
# Artist name from filename: Twisted Sister
# Artist name from filename: Bush (British band)
# Artist name from filename: Audioslave
# Artist name from filename: Flyleaf (band)
# Artist name from filename: The Kinks
# Artist name from filename: Alter Bridge
# Artist name from filename: Paramore
# Artist name from filename: Three Dog Night
# Artist name from filename: Kenny Loggins
# Artist name from filename: 311 (band)
# Artist name from filename: Cream (band)
# Artist name from filename: Ian Dury
# Artist name from filename: Killswitch Engage
# Artist name from filename: W.A.S.P. (band)
# Artist name from filename: Faces (band)
# Artist name from filename: Blondie (band)
# Artist name from filename: The Zombies
#  Is it this one Added node: The Zombies with word count 5581 and happiness average 5.5123426657095
# Artist name from filename: The Guess Who
#  Is it this one Added node: The Guess Who with word count 3343 and happiness average 5.494529214737626
# Artist name from filename: Damn Yankees (band)
# Artist name from filename: Daughtry (band)
# Artist name from filename: Soundgarden
# Artist name from filename: Royal Blood (band)
#  Is it this one Added node: Royal Blood (band) with word count 1799 and happiness average 5.623772919605077
# Artist name from filename: Twenty One Pilots
# Artist name from filename: Bring Me the Horizon
# Artist name from filename: Emerson, Lake & Palmer
# Artist name from filename: Mitch Ryder
# Artist name from filename: The Sweet
# Artist name from filename: Chris Rea
# Artist name from filename: Skid Row (American band)
# Artist name from filename: James Blunt
# Artist name from filename: Stone Temple Pilots
# Artist name from filename: Sublime with Rome
# Artist name from filename: Chuck Berry
# Artist name from filename: Morrissey
# Artist name from filename: Jet (Australian band)
#  Is it this one Added node: Jet (Australian band) with word count 4 and happiness average 5.575
# Artist name from filename: Tool (band)
# Artist name from filename: Duran Duran
# Artist name from filename: Bryan Adams
# Artist name from filename: Jethro Tull (band)
# Artist name from filename: Sum 41
# Artist name from filename: Collective Soul
# Artist name from filename: Manfred Mann
# Artist name from filename: Status Quo (band)
# Artist name from filename: England Dan & John Ford Coley
#  Is it this one Added node: England Dan & John Ford Coley with word count 1197 and happiness average 5.466450216450217
# Artist name from filename: The Police
# Artist name from filename: Journey (band)
# Artist name from filename: Coheed and Cambria
# Artist name from filename: The Killers
# Artist name from filename: John Mayer
# Artist name from filename: April Wine
#  Is it this one Added node: April Wine with word count 2489 and happiness average 5.569041608228144
# Artist name from filename: Sepultura
# Artist name from filename: Tesla (band)
# Artist name from filename: Iron Maiden
#   Added node: Golden Earring with word count 0 and happiness average 5.557598022694079
# Artist name from filename: Jackson Browne
# Artist name from filename: No Doubt
# Artist name from filename: Electric Light Orchestra
# Artist name from filename: Green Day
# Artist name from filename: Jimi Hendrix
# Artist name from filename: Volbeat
# Artist name from filename: Blues Traveler
# Artist name from filename: The Byrds
# Artist name from filename: Vampire Weekend
#   Added node: The Black Keys with word count 0 and happiness average 5.575651465798046
# Artist name from filename: Red Hot Chili Peppers
# Artist name from filename: Bay City Rollers
#  Is it this one Added node: Bay City Rollers with word count 7199 and happiness average 5.531519082534311
# Artist name from filename: Avril Lavigne
# Artist name from filename: The Cars
# Artist name from filename: Elvis Presley
# Artist name from filename: Air Supply
# Artist name from filename: The Yardbirds
# Artist name from filename: Parliament-Funkadelic
# Artist name from filename: John Fogerty
# Artist name from filename: Chris Cornell
# Artist name from filename: Grand Funk Railroad
# Artist name from filename: Beck
# Artist name from filename: Arctic Monkeys
#   Added node: Sam Fender with word count 0 and happiness average 5.509936698844754
# Artist name from filename: Yes (band)
# Artist name from filename: Smash Mouth
#  Is it this one Added node: Smash Mouth with word count 3398 and happiness average 5.519796325878595
# Artist name from filename: Neil Young
# Artist name from filename: Hinder
# Artist name from filename: Jerry Lee Lewis
# Artist name from filename: Megadeth
# Artist name from filename: Ritchie Valens
# Artist name from filename: Supertramp
# Artist name from filename: Drowning Pool
#  Is it this one Added node: Drowning Pool with word count 2014 and happiness average 5.494064990803189
# Artist name from filename: Billy Joel
# Artist name from filename: Five for Fighting
# Artist name from filename: The Monkees
# Artist name from filename: Fleetwood Mac
#   Added node: The Alan Parsons Project with word count 0 and happiness average 5.471413128418859
# Artist name from filename: UB40
#  Is it this one Added node: UB40 with word count 4550 and happiness average 5.514300055772448
# Artist name from filename: Alice Cooper (band)
# Artist name from filename: Kaiser Chiefs
# Artist name from filename: Elvis Costello
# Artist name from filename: Dropkick Murphys
# Artist name from filename: Goo Goo Dolls
# Artist name from filename: Golden Earring
# Artist name from filename: Chicago (band)
# Artist name from filename: The Verve

# %%
# Basic network statistics
print(f"Number of nodes: {G.number_of_nodes()}")
print(f"Number of edges: {G.number_of_edges()}")
print(f"Network density: {nx.density(G):.4f}")
# print some names of nodes
print("Some node names:")
print(list(G.nodes())[:10])  # Print the first 10 node names
# Out:
# Number of nodes: 488
# Number of edges: 7197
# Network density: 0.0303
# Some node names:
# ['Funkadelic', 'Parliament-Funkadelic', 'Sly and the Family Stone', 'Jimi Hendrix', 'Cream (band)', 'Parliament (band)', 'Slayer', 'Ted Nugent', 'Metallica', 'Megadeth']

# %%
degrees = [G.degree(n) for n in G.nodes()]
print(f"Average degree: {sum(degrees)/len(degrees):.2f}")
print(f"Max degree: {max(degrees)}")
print(f"Min degree: {min(degrees)}")
# Out:
# Average degree: 29.50
# Max degree: 147
# Min degree: 0

# %%
# Remove nodes with degree 0 (isolated nodes)
print(f"Original graph: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges")

# Find nodes with degree 0
isolated_nodes = [node for node in G.nodes() if G.degree(node) == 0]
print(f"Found {len(isolated_nodes)} isolated nodes (degree 0)")

if isolated_nodes:
    print(f"Example isolated nodes: {isolated_nodes[:10]}")

# Remove isolated nodes
G.remove_nodes_from(isolated_nodes)

print(f"After removing isolated nodes: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges")

#Alternative: Create a new graph without isolated nodes
G_connected = G.copy()
G_connected.remove_nodes_from([node for node in G_connected.nodes() if G_connected.degree(node) == 0])

# Update the saved network
with open('rock_artists_network.pkl', 'wb') as f:
    pickle.dump(G_connected, f)
    
print("Updated network saved (without isolated nodes)")
# Out:
# Original graph: 488 nodes, 7197 edges
# Found 4 isolated nodes (degree 0)
# Example isolated nodes: ['Dr. Hook & the Medicine Show', 'Van Zant (band)', 'Jet (Australian band)', "The B-52's"]
# After removing isolated nodes: 484 nodes, 7197 edges
# Updated network saved (without isolated nodes)

# %%
# Extract the largest weakly connected component
weakly_connected_components = list(nx.weakly_connected_components(G))
print(f"Number of weakly connected components: {len(weakly_connected_components)}")

# Find the largest component (by number of nodes)
component_sizes = [len(component) for component in weakly_connected_components]
print(f"Component sizes: {sorted(component_sizes, reverse=True)}")

# Get the largest component
largest_component_nodes = max(weakly_connected_components, key=len)
print(f"Largest component has {len(largest_component_nodes)} nodes")

# Create a subgraph containing only the largest component
largest_component = G.subgraph(largest_component_nodes).copy()

print(f"\nLargest component statistics:")
print(f"Number of nodes: {largest_component.number_of_nodes()}")
print(f"Number of edges: {largest_component.number_of_edges()}")
print(f"Network density: {nx.density(largest_component):.4f}")

# Show some example nodes from the largest component
print(f"\nSample nodes from largest component: {list(largest_component_nodes)[:10]}")

# Save the largest component as a separate graph
with open('largest_component.pkl', 'wb') as f:
    pickle.dump(largest_component, f)
    
print("\nLargest component saved as 'largest_component.pkl'")
# Out:
# Number of weakly connected components: 1
# Component sizes: [484]
# Largest component has 484 nodes
#
# Largest component statistics:
# Number of nodes: 484
# Number of edges: 7197
# Network density: 0.0308
#
# Sample nodes from largest component: ['Flyleaf (band)', 'Ted Nugent', 'James Taylor', 'Kings of Leon', 'Harry Nilsson', 'Collective Soul', 'Dave Matthews Band', 'The Allman Brothers Band', 'R.E.M.', 'Little River Band']
#
# Largest component saved as 'largest_component.pkl'
