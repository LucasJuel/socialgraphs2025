# %%
import networkx as nx
import matplotlib.pyplot as plt
import re
import os
import glob
import requests
import json
from collections import defaultdict

# %% [markdown]
# ##Part 1

# %%
import urllib.request
response = urllib.request.urlopen('http://www.example.com/')
html = response.read()

print(html)
# Out:
# b'<!doctype html><html lang="en"><head><title>Example Domain</title><meta name="viewport" content="width=device-width, initial-scale=1"><style>body{background:#eee;width:60vw;margin:15vh auto;font-family:system-ui,sans-serif}h1{font-size:1.5em}div{opacity:0.8}a:link,a:visited{color:#348}</style><body><div><h1>Example Domain</h1><p>This domain is for use in documentation examples without needing permission. Avoid use in operations.<p><a href="https://iana.org/domains/example">Learn more</a></div></body></html>\n'

# %%
import pickle
import csv
from statistics import mean


with open('Cleaned_Rock_Musicians.txt', 'r', encoding='utf-8') as g:
    allArtists_text = g.read()


# Get all txt files in the wiki_pages directory
wiki_files = glob.glob('wiki_pages/*.txt')
print(f"Found {len(wiki_files)} txt files in wiki_pages directory")


def load_labmt_lexicon(filename='Data_Set_S1.txt'):
    """
    Loads the labMT (S1) dataset (tab-separated) and returns {word: happiness_average(float)}.
    Lines with '--' are skipped. Header must include 'word' and 'happiness_average'.
    """
    lex = {}
    with open(filename, encoding='utf-8') as f:
        reader = csv.DictReader(f, delimiter='\t')
        for row in reader:
            w = (row.get('word') or '').strip().lower()
            v = (row.get('happiness_average') or '').strip()
            if not w or v in ('', '--'):
                continue
            try:
                lex[w] = float(v)
            except ValueError:
                pass
    return lex

# precompile a plain-word tokenizer (letters only, case-insensitive)
_TOKEN_RE = re.compile(r"[A-Za-z]+")

# --- 2) Compute average happiness for a page's text ---
def page_happiness_average(text, lexicon):
    """
    Returns (avg_happiness, matched_count, token_count).
    Only words found in lexicon contribute to the average.
    """
    if not text:
        return (None, 0, 0)
    tokens = _TOKEN_RE.findall(text.lower())
    token_count = len(tokens)
    if token_count == 0:
        return (None, 0, 0)
    vals = [lexicon[t] for t in tokens if t in lexicon]
    if not vals:
        return (None, 0, token_count)
    return (mean(vals), len(vals), token_count)


artist_set = set()
for line in allArtists_text.strip().split('\n'):
    artist_name = line.strip()
    if artist_name:  # Skip empty lines
        artist_set.add(artist_name)

# Initialize lists to store all results
lexicon = load_labmt_lexicon("Data_Set_S1.txt")
file_results = {}

G = nx.DiGraph()

# Regular expression to match Wikipedia links
wiki_link_pattern = r'\[\[([^\[\]|]+)(?:\|[^\[\]]+)?\]\]'

url2 = 'https://raw.githubusercontent.com/LucasJuel/socialgraphs2025/main/assignments/Assignment%202/artist_genres_without_rock.json'
response2 = requests.get(url2)
artist_genres = response2.json()


# Process each file
for file_path in wiki_files:
    try:
        #print(f"\nProcessing file: {file_path}")

        artist_name = os.path.basename(file_path).replace('.txt', '')
        artist_name = artist_name.replace('_', ' ').strip()

        if artist_name not in artist_set:
            print(f"Skipping {artist_name} - not in original artist list")
            continue

        print(f"Artist name from filename: {artist_name}")
        # Read the file
        with open(file_path, 'r', encoding='utf-8') as f:
            text = f.read()
        
        # Extract all matches
        matches = re.findall(wiki_link_pattern, text)
        
        # Get unique links for this file
        unique_links = list(set(matches))
        
        # Check which links are found in the allArtists_text list
        found_in_artists = []

        # First remove common wiki markup
        clean_text = text
        clean_text = re.sub(r'\[\[.*?\]\]', ' ', clean_text)  # Remove links
        clean_text = re.sub(r'\{\{.*?\}\}', ' ', clean_text)  # Remove templates
        clean_text = re.sub(r'<.*?>', ' ', clean_text)  # Remove HTML tags
        clean_text = re.sub(r'==.*?==', ' ', clean_text)  # Remove headers
        clean_text = re.sub(r'\|.*?\|', ' ', clean_text)  # Remove table markup

        for word in clean_text.split():
            if word.startswith('File:') or word.startswith('Image:'):
                clean_text = clean_text.replace(word, ' ')

        # Count how many times each genre appears in this artist's page (case-insensitive)
        clean_text_lower = text.lower()

        genre_counts = {}
        for genre in artist_genres.get(artist_name.replace('(band)', '').strip(), []):
            # Use regex with word boundaries to match complete genre phrases
            pattern = r'\b' + re.escape(genre.lower()) + r'\b'
            matches = re.findall(pattern, clean_text_lower)
            genre_counts[genre] = len(matches)

        print("Lookey here", genre_counts)
        # Now count actual words (sequences of word characters)
        words = re.findall(r'\b\w+\b', clean_text.lower())

        word_count = len(words)
        avg, total, matched = page_happiness_average(clean_text, lexicon)

        if( artist_name not in G.nodes()):
            G.add_node(artist_name, word_count=word_count, happiness_average=avg, genres=genre_counts)
            #print(f" Is it this one Added node: {artist_name} with word count {word_count} and happiness average {avg} the genre counts are {genre_counts}  ")
        else:
            G.nodes[artist_name]['word_count'] = word_count
            G.nodes[artist_name]['happiness_average'] = avg
            G.nodes[artist_name]['genres'] = genre_counts

        
        for link in unique_links:
            if link not in artist_set:
                continue  # Skip links not containing artists
            link_normalised = link.replace('_', ' ').strip()

            if link_normalised == artist_name:
                continue  # Skip self-loops

            if link_normalised not in G.nodes():
                G.add_node(link_normalised, word_count=0, happiness_average=avg, genres=genre_counts)  # Add node with zero word count if not present
                #print(f"  Added node: {link_normalised} with word count 0 and happiness average {avg}")

            if link_normalised in artist_set:
                G.add_edge(artist_name, link_normalised)
                #print(f"  Found link to artist: {link_normalised}")
                found_in_artists.append(link_normalised)

        
        # Print results for this file
        #print(f"\n{artist_name}:")
        #print(f"  Found edges: {len(found_in_artists)}")


        #with open('rock_network.pkl', 'wb') as f:
         #   pickle.dump(G, f)

    
    
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
# Out:
# Found 489 txt files in wiki_pages directory
# Artist name from filename: 10cc
# Lookey here {'art rock': 3, 'art pop': 3, 'progressive pop': 2, 'soft rock': 2, 'pop rock': 1}
# Artist name from filename: 10 Years (band)
# Lookey here {'alternative metal': 5, 'progressive metal': 3, 'post-grunge': 3, 'nu&nbsp': 1, 'metal': 14}
# Artist name from filename: 311 (band)
# Lookey here {'alternative rock': 3, 'rap rock': 3, 'reggae rock': 3, 'funk rock': 3, 'funk metal': 3}
# Artist name from filename: 38 Special (band)
# Lookey here {'hard rock': 3, 'southern rock': 5, 'boogie rock': 1, 'blues rock': 2}
# Artist name from filename: 3 Doors Down
# Lookey here {'post-grunge': 3, 'alternative rock': 3}
# Artist name from filename: ABBA
# Lookey here {'pop music': 3, 'pop': 35, 'disco': 3, 'pop rock': 2, 'europop': 2}
# Artist name from filename: Accept (band)
# Lookey here {'heavy metal music': 2, 'heavy metal': 9}
# Skipping AC DC - not in original artist list
# Artist name from filename: Adam Ant
# Lookey here {'new wave music': 2, 'new wave': 7, 'post-punk': 1, 'alternative rock': 1, 'dance-rock': 1}
# Artist name from filename: Aerosmith
# Lookey here {'hard rock': 13, 'blues rock': 5, 'heavy metal music': 3, 'heavy metal': 11}
# Artist name from filename: AFI (band)
# Lookey here {'punk rock': 6, 'gothic rock': 8, 'horror punk': 8, 'post-hardcore': 7, 'emo': 14, 'hardcore punk (early)': 0}
# Artist name from filename: Air Supply
# Lookey here {'soft rock': 6, 'pop rock': 1, 'pop music': 7, 'pop': 12, 'adult contemporary music': 1, 'adult contemporary': 11, 'middle of the road (music)': 0, 'middle-of-the-road': 1}
# Artist name from filename: Alanis Morissette
# Lookey here {'alternative rock': 3, 'post-grunge': 2, 'electronica': 1, 'grunge': 3, 'trip hop': 1, 'indie pop': 1, 'pop rock': 1}
# Artist name from filename: Alice Cooper
# Lookey here {'hard rock': 3, 'glam rock': 4, 'shock rock': 11, 'psychedelic rock (early)': 0}
# Artist name from filename: Alice Cooper (band)
# Lookey here {'hard rock': 5, 'glam rock': 7, 'shock rock': 3, 'psychedelic rock (early)': 0}
# Artist name from filename: Alice in Chains
# Lookey here {'grunge': 39, 'alternative metal': 6, 'heavy metal music': 3, 'heavy metal': 13, 'alternative rock': 5, 'sludge metal': 3}
# Skipping AllMusic - not in original artist list
# Artist name from filename: Alter Bridge
# Lookey here {'hard rock': 10, 'heavy metal music': 5, 'heavy metal': 8, 'alternative metal': 3, 'progressive metal': 5, 'alternative rock': 2, 'post-grunge': 3}
# Artist name from filename: Ambrosia (band)
# Lookey here {'progressive rock': 4, 'soft rock': 2, 'jazz fusion': 1, 'blue-eyed soul': 2}
# Artist name from filename: America (band)
# Lookey here {'soft rock': 3, 'folk rock': 3, 'pop rock': 2, 'country rock': 1}
# Artist name from filename: Anthrax (American band)
# Lookey here {}
# Artist name from filename: April Wine
# Lookey here {'hard rock': 4}
# Artist name from filename: Arcade Fire
# Lookey here {'indie rock': 6, 'art rock': 3, 'dance-rock': 2, 'baroque pop': 2}
# Artist name from filename: Arctic Monkeys
# Lookey here {'indie rock': 10, 'garage rock': 9, 'post-punk revival': 7, 'psychedelic rock': 6, 'alternative rock': 7, 'lounge music': 3, 'lounge pop': 4}
# Artist name from filename: Asia (band)
# Lookey here {'progressive rock': 12, 'arena rock': 2, 'aor': 5, 'pop rock': 1}
# Artist name from filename: Audioslave
# Lookey here {'hard rock': 9, 'alternative metal': 3, 'post-grunge': 3, 'alternative rock': 5}
# Artist name from filename: Avenged Sevenfold
# Lookey here {'heavy metal music': 4, 'heavy metal': 20, 'progressive metal': 6, 'alternative metal': 3, 'hard rock': 6, 'metalcore (early)': 0}
# Artist name from filename: Avril Lavigne
# Lookey here {'pop-punk': 45, 'alternative rock': 6, 'pop rock': 9, 'pop music': 4, 'pop': 160}
# Artist name from filename: Awolnation
# Lookey here {}
# Artist name from filename: A Perfect Circle
# Lookey here {'alternative rock': 4, 'alternative metal': 4, 'hard rock': 5, 'art rock': 4}
# Skipping Bachman-Turner Overdrive - not in original artist list
# Artist name from filename: Badfinger
# Lookey here {'power pop': 3}
# Artist name from filename: Bad Company
# Lookey here {'hard rock': 5, 'blues rock': 2}
# Artist name from filename: Barenaked Ladies
# Lookey here {'alternative pop': 2, 'folk rock': 2, 'pop rock': 1, 'comedy rock': 3}
# Artist name from filename: Bay City Rollers
# Lookey here {'pop music': 2, 'pop': 23, 'glam rock': 2, 'pop rock': 4}
# Artist name from filename: Beastie Boys
# Lookey here {'hip-hop': 24, 'rap rock': 3, 'alternative hip-hop': 3, 'hardcore punk (early)': 0}
# Artist name from filename: Beck
# Lookey here {'alternative rock': 6, 'folk rock': 1, 'psychedelia': 4, 'electronic music': 5, 'electronic': 10, 'alternative country': 2, 'alt-country': 1, 'lo-fi music': 2, 'lo-fi (early)': 0}
# Artist name from filename: Bee Gees
# Lookey here {'pop music': 4, 'pop': 47, 'soul music': 3, 'soul': 7, 'disco': 30, 'soft rock': 3}
# Artist name from filename: Ben Folds Five
# Lookey here {'alternative rock': 4, 'power pop': 2}
# Artist name from filename: Billy Idol
# Lookey here {'new wave music': 2, 'new wave': 11, 'hard rock': 6, 'pop rock': 2, 'punk rock': 7}
# Artist name from filename: Billy Joel
# Lookey here {'soft rock': 4, 'pop rock': 3}
# Artist name from filename: Billy Squier
# Lookey here {'hard rock': 6, 'arena rock': 3, 'pop rock': 1, 'power pop': 2}
# Artist name from filename: Billy Talent
# Lookey here {'punk rock': 6, 'alternative rock': 2, 'post-hardcore': 3, 'pop-punk': 3}
# Artist name from filename: Bill Haley & His Comets
# Lookey here {'rock and roll': 32, 'rockabilly': 9, 'western swing (early)': 0}
# Artist name from filename: Black Sabbath
# Lookey here {'heavy metal music': 4, 'heavy metal': 41}
# Artist name from filename: Black Stone Cherry
# Lookey here {'hard rock': 4, 'southern rock': 2}
# Artist name from filename: Black Veil Brides
# Lookey here {'hard rock': 4, 'alternative metal': 3, 'glam metal': 6, 'gothic metal': 3, 'metalcore': 4}
# Artist name from filename: Blink-182
# Lookey here {'pop-punk': 22, 'punk rock': 19, 'skate punk': 4, 'alternative rock': 3}
# Artist name from filename: Blondie (band)
# Lookey here {'new wave music': 3, 'new wave': 8, 'punk rock': 3, 'pop rock': 2, 'pop music': 3, 'pop': 26, 'disco': 6}
# Artist name from filename: Bloodhound Gang
# Lookey here {'alternative rock': 3, 'rap rock': 2, 'pop-punk': 1, 'new wave music': 2, 'new wave': 4}
# Artist name from filename: Blues Traveler
# Lookey here {'blues rock': 3, 'folk rock': 3, 'alternative rock': 3, 'southern rock': 3, 'jam band': 2}
# Artist name from filename: Blue October
# Lookey here {'alternative rock': 4, 'art rock': 2, 'post-grunge': 2, 'new wave music': 1, 'new wave': 2, 'synth-pop': 1, 'shoegaze': 1}
# Artist name from filename: Blue Öyster Cult
# Lookey here {'hard rock': 10, 'heavy metal music': 4, 'heavy metal': 17, 'occult rock': 4, 'psychedelic rock': 4, 'progressive rock': 3, 'acid rock': 2}
# Artist name from filename: Blur (band)
# Lookey here {'britpop': 31, 'indie rock': 5, 'alternative rock': 6, 'art pop': 2}
# Artist name from filename: Bob Dylan
# Lookey here {'contemporary folk music': 1, 'folk': 53, 'blues': 24, 'gospel music': 3, 'gospel': 14, 'country music': 3, 'country': 41, 'traditional pop': 2}
# Artist name from filename: Bob Seger
# Lookey here {'heartland rock': 2, 'roots rock': 2}
# Artist name from filename: Bon Jovi
# Lookey here {'hard rock': 7, 'glam metal': 6, 'arena rock': 3, 'pop rock': 3}
# Artist name from filename: Boston (band)
# Lookey here {'hard rock': 6, 'arena rock': 3}
# Artist name from filename: Bowling for Soup
# Lookey here {'pop-punk': 5, 'pop rock': 3, 'alternative rock': 2, 'power pop': 3}
# Artist name from filename: Boys Like Girls
# Lookey here {'pop rock': 4, 'pop-punk': 2, 'emo pop': 2}
# Artist name from filename: Bo Diddley
# Lookey here {'rock and roll': 15, 'blues': 55, 'psychedelic funk': 3}
# Artist name from filename: Bread (band)
# Lookey here {'soft rock': 4}
# Artist name from filename: Breaking Benjamin
# Lookey here {'hard rock': 8, 'post-grunge': 5, 'alternative metal': 7, 'alternative rock': 5}
# Artist name from filename: Bring Me the Horizon
# Lookey here {'metalcore': 16, 'alternative metal': 7, 'alternative rock': 6, 'post-hardcore': 10, 'pop rock': 6, 'electronic rock': 5, 'deathcore (early)': 0}
# Artist name from filename: Bruce Springsteen
# Lookey here {'heartland rock': 3, 'folk music': 1, 'folk': 11, 'pop rock': 3}
# Artist name from filename: Bryan Adams
# Lookey here {'pop rock': 5, 'soft rock': 4, 'arena rock': 2, 'heartland rock': 1}
# Artist name from filename: Bryan Ferry
# Lookey here {'pop rock': 1, 'glam rock': 2, 'art rock': 2, 'sophisti-pop': 2}
# Artist name from filename: Buckcherry
# Lookey here {'hard rock': 6, 'alternative metal': 1, 'sleaze rock': 1}
# Artist name from filename: Buddy Holly
# Lookey here {'rock and roll': 19, 'rockabilly': 3, 'pop music': 2, 'pop': 6}
# Artist name from filename: Bullet for My Valentine
# Lookey here {'melodic metalcore': 2, 'heavy metal music': 3, 'heavy metal': 12, 'thrash metal': 4, 'hard rock': 4}
# Artist name from filename: Bush (British band)
# Lookey here {}
# Artist name from filename: Cage the Elephant
# Lookey here {'alternative rock': 11, 'indie rock': 2, 'psychedelic rock': 3, 'garage rock': 4, 'punk blues': 2, 'post-punk': 1}
# Artist name from filename: Cake (band)
# Lookey here {'alternative rock': 3, 'country music': 3, 'country': 5, 'indie rock': 1, 'funk rock': 1}
# Artist name from filename: Canned Heat
# Lookey here {'blues rock': 4, 'boogie rock': 2}
# Artist name from filename: Catfish and the Bottlemen
# Lookey here {'alternative rock': 1, 'indie rock': 4, 'post-punk revival': 1}
# Artist name from filename: Charlie Daniels
# Lookey here {'southern rock': 15, 'country rock': 4, 'progressive country': 4, 'bluegrass music': 2, 'bluegrass': 9}
# Artist name from filename: Cheap Trick
# Lookey here {'power pop': 6, 'hard rock': 3}
# Artist name from filename: Chevelle (band)
# Lookey here {'hard rock': 7, 'alternative metal': 4, 'alternative rock': 6, 'post-grunge': 4, 'nu metal': 5}
# Artist name from filename: Chicago (band)
# Lookey here {'soft rock': 2, 'pop rock': 1, 'jazz rock': 3}
# Artist name from filename: Christopher Cross
# Lookey here {'pop music': 1, 'pop': 10, 'soft rock': 2, 'yacht rock': 2}
# Artist name from filename: Chris Cornell
# Lookey here {'alternative metal': 3, 'heavy metal music': 2, 'heavy metal': 8, 'grunge': 30, 'alternative rock': 5, 'hard rock': 3}
# Artist name from filename: Chris de Burgh
# Lookey here {'art rock': 4, 'pop music': 2, 'pop': 8}
# Artist name from filename: Chris Rea
# Lookey here {'pop rock': 1, 'soft rock': 2, 'electric blues': 2, 'blues rock': 1}
# Artist name from filename: Chubby Checker
# Lookey here {'rock and roll': 9}
# Artist name from filename: Chuck Berry
# Lookey here {'rock and roll': 42, 'rhythm and blues': 8}
# Artist name from filename: Cinderella (band)
# Lookey here {'glam metal': 7, 'hard rock': 3, 'blues rock': 5}
# Artist name from filename: Coheed and Cambria
# Lookey here {}
# Artist name from filename: Coldplay
# Lookey here {'alternative rock': 5, 'pop rock': 5, 'post-britpop': 3, 'pop music': 3, 'pop': 49}
# Artist name from filename: Cold Chisel
# Lookey here {'pub rock (australia)': 0, 'pub rock': 5, 'rhythm and blues': 2, 'r&b': 1, 'hard rock': 9, 'rock and roll': 1}
# Artist name from filename: Collective Soul
# Lookey here {'alternative rock': 3, 'hard rock': 4, 'post-grunge': 3}
# Artist name from filename: Counting Crows
# Lookey here {'alternative rock': 3, 'roots rock': 1, 'pop rock': 2}
# Artist name from filename: Crash Test Dummies
# Lookey here {'alternative rock': 3, 'folk rock': 3}
# Artist name from filename: Cream (band)
# Lookey here {'psychedelic rock': 3, 'blues rock': 4, 'acid rock': 2, 'hard rock': 9}
# Artist name from filename: Creedence Clearwater Revival
# Lookey here {}
# Artist name from filename: Creed (band)
# Lookey here {'post-grunge': 13, 'hard rock': 8, 'alternative rock': 4, 'alternative metal': 4}
# Artist name from filename: Crosby, Stills, Nash & Young
# Lookey here {'folk rock': 7, 'soft rock': 3, 'country rock': 3, 'folk pop': 1}
# Artist name from filename: Crowded House
# Lookey here {'pop rock': 3, 'jangle pop': 3, 'alternative rock': 2}
# Artist name from filename: Dallas Green (musician)
# Lookey here {}
# Artist name from filename: Damn Yankees (band)
# Lookey here {'hard rock': 2, 'arena rock': 1}
# Artist name from filename: Dan Fogelberg
# Lookey here {'country music': 1, 'country': 9, 'folk music': 1, 'folk': 6, 'folk rock': 1, 'soft rock': 5, 'pop rock': 1, 'pop music': 1, 'pop': 7}
# Artist name from filename: Dashboard Confessional
# Lookey here {'emo': 7, 'alternative rock': 3, 'indie rock': 3, 'acoustic rock': 2}
# Artist name from filename: Daughtry (band)
# Lookey here {'post-grunge': 2, 'hard rock': 2, 'pop rock': 3}
# Artist name from filename: Dave Matthews Band
# Lookey here {'jam rock': 1}
# Artist name from filename: David Bowie
# Lookey here {'art rock': 2, 'glam rock': 8, 'pop music': 3, 'pop': 43, 'electronic music': 3, 'electronic': 11}
# Artist name from filename: Days of the New
# Lookey here {'post-grunge': 2, 'alternative rock': 3, 'alternative metal': 1}
# Artist name from filename: Death Cab for Cutie
# Lookey here {'indie rock': 7, 'alternative rock': 5, 'indie pop': 5, 'emo (early)': 0}
# Artist name from filename: Deep Purple
# Lookey here {'hard rock': 22, 'heavy metal music': 5, 'heavy metal': 23, 'progressive rock': 7}
# Artist name from filename: Deftones
# Lookey here {'alternative metal': 11, 'art rock': 4, 'shoegaze': 5, 'nu metal (early)': 0}
# Artist name from filename: Def Leppard
# Lookey here {'hard rock': 17, 'glam metal': 6, 'arena rock': 6, 'power pop': 2, 'heavy metal music': 4, 'heavy metal (early)': 0}
# Artist name from filename: Depeche Mode
# Lookey here {'synth-pop': 7, 'alternative dance': 2, 'alternative rock': 5, 'dance-rock': 3, 'dark wave': 3, 'electronic dance music': 2, 'edm': 2, 'electronic rock': 3, 'industrial music': 3, 'industrial': 11, 'new wave music': 3, 'new wave': 8, 'pop rock': 2, 'post-punk': 7}
# Artist name from filename: Dio (band)
# Lookey here {'heavy metal music': 2, 'heavy metal': 9}
# Artist name from filename: Dire Straits
# Lookey here {'roots rock': 3, 'blues rock': 4, 'pub rock (united kingdom)': 0, 'pub rock': 5}
# Artist name from filename: Disturbed (band)
# Lookey here {'heavy metal music': 4, 'heavy metal': 14, 'alternative metal': 3, 'hard rock': 9, 'nu metal (early)': 0}
# Artist name from filename: Donovan
# Lookey here {'folk rock': 3, 'folk': 30, 'pop music': 3, 'pop': 17, 'psychedelic music': 2, 'psychedelia': 3}
# Artist name from filename: Don Henley
# Lookey here {'country rock': 2, 'pop rock': 1, 'hard rock': 1, 'folk rock': 2}
# Artist name from filename: Dr. Hook & the Medicine Show
# Lookey here {}
# Artist name from filename: Dropkick Murphys
# Lookey here {'celtic punk': 8, 'folk punk': 2, 'street punk': 3, 'oi!': 0, 'hardcore punk': 2}
# Artist name from filename: Drowning Pool
# Lookey here {}
# Artist name from filename: Duane Eddy
# Lookey here {'instrumental rock': 1, 'rockabilly': 8, 'rock and roll': 9, 'country music': 6, 'country': 19}
# Artist name from filename: Duran Duran
# Lookey here {'pop rock': 5, 'synth-pop': 7, 'new wave music': 3, 'new wave': 7, 'dance-rock': 3}
# Artist name from filename: Eagles (band)
# Lookey here {'country rock': 11, 'soft rock': 3, 'folk rock': 4}
# Artist name from filename: Echo & the Bunnymen
# Lookey here {'post-punk': 2, 'new wave music': 2, 'new wave': 5, 'neo-psychedelia': 2}
# Artist name from filename: Eddie Cochran
# Lookey here {'rock and roll': 13, 'rockabilly': 7, 'country music': 1, 'country': 6, 'rhythm and blues': 2}
# Artist name from filename: Eddie Money
# Lookey here {'pop rock': 1, 'hard rock': 2}
# Artist name from filename: Edgar Winter
# Lookey here {'southern rock': 2, 'pop music': 1, 'pop': 4, 'jazz fusion': 1, 'blues rock': 1, 'blue-eyed soul': 1, 'boogie rock': 1}
# Artist name from filename: Electric Light Orchestra
# Lookey here {'progressive pop': 2, 'progressive rock': 5, 'orchestral pop': 2, 'art rock': 3}
# Artist name from filename: Elton John
# Lookey here {'pop rock': 1, 'glam rock': 5, 'soft rock': 3, 'blues': 5}
# Artist name from filename: Elvis Costello
# Lookey here {'pop music': 3, 'pop': 29, 'new wave music': 3, 'new wave': 15, 'power pop': 1, 'punk rock': 6, 'pub rock (united kingdom)': 0, 'pub rock': 6}
# Artist name from filename: Elvis Presley
# Lookey here {'rock and roll': 34, 'pop music': 5, 'pop': 29, 'rockabilly': 17, 'country music': 13, 'country': 49, 'gospel music': 7, 'gospel': 33, 'r&b': 8, 'blue-eyed soul': 2, 'soul': 11, 'blues': 43}
# Artist name from filename: Emerson, Lake & Palmer
# Lookey here {'progressive rock': 12, 'art rock': 3}
# Artist name from filename: England Dan & John Ford Coley
# Lookey here {'pop rock': 1, 'soft rock': 6, 'country rock': 1}
# Artist name from filename: Eric Clapton
# Lookey here {'blues': 68}
# Artist name from filename: Europe (band)
# Lookey here {'arena rock': 1, 'hard rock': 4, 'glam metal': 3, 'blues rock': 2}
# Artist name from filename: Evanescence
# Lookey here {}
# Artist name from filename: Everclear (band)
# Lookey here {'alternative rock': 8, 'power pop': 4, 'post-grunge': 3, 'pop rock': 3, 'grunge (early)': 0, 'punk rock (early)': 0}
# Artist name from filename: Everlast
# Lookey here {'hip hop music': 4, 'hip hop': 9, 'folk rock': 2, 'blues': 11}
# Artist name from filename: Extreme (band)
# Lookey here {'hard rock': 5, 'funk metal': 3, 'glam metal': 4}
# Artist name from filename: Faces (band)
# Lookey here {'blues': 2}
# Artist name from filename: Faith No More
# Lookey here {'alternative metal': 9, 'funk metal': 4, 'alternative rock': 8, 'experimental rock': 3}
# Artist name from filename: Fall Out Boy
# Lookey here {'pop-punk': 27, 'pop rock': 5, 'emo': 25, 'alternative rock': 4}
# Artist name from filename: Fats Domino
# Lookey here {'rock and roll': 23, 'new orleans r&b': 1, 'boogie-woogie': 6, 'blues': 18}
# Artist name from filename: Filter (band)
# Lookey here {'industrial rock': 5, 'post-grunge': 7, 'alternative rock': 3, 'hard rock': 3, 'industrial metal': 6, 'alternative metal': 4}
# Artist name from filename: Finger Eleven
# Lookey here {'alternative rock': 2, 'alternative metal': 2, 'hard rock': 2, 'nu metal': 2}
# Artist name from filename: FireHouse
# Lookey here {'glam metal': 3, 'hard rock': 5}
# Artist name from filename: Five Finger Death Punch
# Lookey here {'groove metal': 4, 'alternative metal': 3, 'hard rock': 3}
# Artist name from filename: Five for Fighting
# Lookey here {'soft rock': 4, 'heartland rock': 2, 'alternative rock': 2, 'pop rock': 4, 'americana (music)': 0, 'americana': 6, 'adult contemporary': 11}
# Artist name from filename: Fleetwood Mac
# Lookey here {'pop rock': 5, 'soft rock': 3, 'blues rock': 4, 'art pop': 2}
# Artist name from filename: Flogging Molly
# Lookey here {'celtic punk': 5, 'folk punk': 2}
# Artist name from filename: Florence and the Machine
# Lookey here {'indie rock': 4, 'indie pop': 3, 'chamber pop': 2, 'baroque pop': 2, 'art pop': 2, 'art rock': 4, 'neo soul': 2, 'folk (music)': 0, 'folk': 5}
# Artist name from filename: Flyleaf (band)
# Lookey here {}
# Artist name from filename: Foals (band)
# Lookey here {'indie rock': 4, 'alternative rock': 3, 'math rock': 4, 'art rock': 2, 'dance-punk': 3}
# Artist name from filename: Foo Fighters
# Lookey here {'alternative rock': 4, 'post-grunge': 4, 'hard rock': 6}
# Artist name from filename: Foreigner (band)
# Lookey here {'hard rock': 5, 'soft rock': 3, 'arena rock': 2}
# Artist name from filename: Foster the People
# Lookey here {'indie pop': 6, 'synth-pop': 4, 'dance-pop': 2, 'alternative rock': 4, 'indie rock': 2, 'neo-psychedelia': 3}
# Artist name from filename: Frank Zappa
# Lookey here {'progressive rock': 5, 'blues': 10, 'experimental music': 4, 'experimental': 17, 'jazz': 53, 'jazz fusion': 4, 'fusion': 9, 'classical music': 12, 'classical': 27, 'pop music': 5, 'pop': 18, 'avant-garde music': 1, 'avant-garde': 11, 'doo-wop': 9, 'comedy music': 1, 'comedy': 10, 'electronic music': 2, 'electronic': 9, 'musique concrète': 3}
# Artist name from filename: Franz Ferdinand (band)
# Lookey here {'indie rock': 4, 'post-punk revival': 4, 'dance-punk': 3, 'art rock': 3, 'art punk': 2}
# Artist name from filename: Fuel (band)
# Lookey here {'alternative rock': 3, 'hard rock': 2, 'post-grunge': 2, 'alternative metal': 2}
# Artist name from filename: Funkadelic
# Lookey here {'funk rock': 4, 'psychedelic funk': 2, 'acid rock': 2, 'psychedelic rock': 5}
# Artist name from filename: Fun (band)
# Lookey here {'indie pop': 2, 'indie rock': 2, 'pop rock': 2, 'baroque pop': 1}
# Artist name from filename: Garbage (band)
# Lookey here {'alternative rock': 4, 'electronic rock': 3, 'dance-rock': 2, 'trip hop': 5, 'industrial rock': 5}
# Artist name from filename: Gary Glitter
# Lookey here {'glam rock': 7, 'rock and roll': 20, 'pop rock': 2, 'hard rock': 2, 'disco': 3}
# Artist name from filename: Genesis (band)
# Lookey here {'progressive rock': 9, 'art rock': 5, 'pop rock': 3, 'soft rock': 3}
# Artist name from filename: Gene Vincent
# Lookey here {'rockabilly': 12, 'rock and roll': 12, 'country music': 4, 'country': 15}
# Artist name from filename: George Harrison
# Lookey here {'pop music': 2, 'pop': 15, 'indian classical music': 4, 'indian classical': 5}
# Artist name from filename: George Thorogood
# Lookey here {'blues rock': 3, 'hard rock': 2, 'boogie rock': 1, 'rock and roll': 4}
# Artist name from filename: Ghost (Swedish band)
# Lookey here {}
# Artist name from filename: Gin Blossoms
# Lookey here {'alternative rock': 5, 'jangle pop': 4, 'power pop': 3, 'post-grunge': 5, 'country rock': 1}
# Artist name from filename: Glenn Frey
# Lookey here {'pop rock': 1, 'soft rock': 1, 'country rock (early)': 0, 'hard rock (later)': 0}
# Artist name from filename: Godsmack
# Lookey here {}
# Artist name from filename: Golden Earring
# Lookey here {'hard rock': 3, 'blues rock': 1, 'jazz rock': 1, 'psychedelic rock': 2, 'garage rock': 1}
# Artist name from filename: Good Charlotte
# Lookey here {'pop-punk': 8, 'alternative rock': 4, 'emo': 13, 'pop rock': 3}
# Artist name from filename: Goo Goo Dolls
# Lookey here {'alternative rock': 4, 'pop rock': 3, 'post-grunge': 2, 'punk rock <small>(early)<': 0, 'small>': 0}
# Artist name from filename: Grand Funk Railroad
# Lookey here {'hard rock arena rock': 0}
# Artist name from filename: Grateful Dead
# Lookey here {}
# Artist name from filename: Great White
# Lookey here {'hard rock': 5, 'glam metal': 3}
# Artist name from filename: Green Day
# Lookey here {'punk rock': 31, 'pop-punk': 5, 'alternative rock': 6, 'skate punk': 4, 'power pop': 4}
# Artist name from filename: Greta Van Fleet
# Lookey here {'hard rock': 7, 'blues rock': 4, 'progressive rock': 2}
# Artist name from filename: Guns N' Roses
# Lookey here {'hard rock': 21, 'heavy metal music': 6, 'heavy metal': 25}
# Artist name from filename: Halestorm
# Lookey here {'hard rock': 9, 'heavy metal music': 1, 'heavy metal': 5, 'alternative metal': 2, 'post-grunge': 2}
# Artist name from filename: Hall & Oates
# Lookey here {'pop rock': 1, 'blue-eyed soul': 1, 'soft&nbsp': 1, 'rhythm and blues': 3, 'r&b': 6}
# Artist name from filename: Harry Chapin
# Lookey here {'folk rock': 3, 'pop rock': 3}
# Artist name from filename: Harry Nilsson
# Lookey here {'pop music': 2, 'pop': 12}
# Artist name from filename: Heart (band)
# Lookey here {'hard rock': 15, 'folk rock': 3, 'pop rock': 1, 'heavy metal music': 2, 'heavy metal': 6}
# Artist name from filename: Herman's Hermits
# Lookey here {'beat music': 2, 'beat': 6, 'pop rock': 2, 'bubblegum music': 1, 'bubblegum': 2}
# Artist name from filename: Highly Suspect
# Lookey here {'alternative rock': 3, 'hard rock': 5, 'blues rock': 2, 'grunge': 2, 'garage rock': 2}
# Artist name from filename: Hinder
# Lookey here {'post-grunge': 4, 'hard rock': 6}
# Artist name from filename: Hole (band)
# Lookey here {'alternative rock': 7, 'grungesfn': 0, 'kallen': 3, '2012': 58, 'p=78': 2, 'punk rocksfn': 0, 'hogg': 2, 'p=42': 1, 'noise rocksfn': 0, 'anderson': 3, 'p=213': 1, 'power pop': 3}
# Artist name from filename: Hoobastank
# Lookey here {'alternative rock': 4, 'nu metal': 3, 'post-grunge': 3, 'funk metal (early)': 0, 'ska punk (early)': 0}
# Artist name from filename: Hootie & the Blowfish
# Lookey here {'pop rock': 2, 'alternative rock': 3, 'soft rock': 2, 'roots rock': 2, 'heartland rock': 2, 'jangle pop': 1}
# Artist name from filename: Huey Lewis and the News
# Lookey here {'new wave music': 3, 'new wave': 6, 'rhythm & blues': 3}
# Artist name from filename: Ian Dury
# Lookey here {'new wave music': 3, 'new wave': 8, 'punk rock': 4, 'post-punk': 1, 'funk': 2, 'disco': 1, 'pub rock (united kingdom)': 0, 'pub rock': 5}
# Artist name from filename: Icehouse (band)
# Lookey here {'new wave music': 2, 'new wave': 6, 'synth-pop': 4}
# Artist name from filename: Iggy Pop
# Lookey here {'punk rock': 3, 'proto-punk': 4, 'hard rock': 3, 'garage rock': 2}
# Artist name from filename: Imagine Dragons
# Lookey here {'pop rock': 5, 'electropop': 2, 'pop music': 4, 'pop': 36, 'arena rock': 5, 'alternative rock': 4, 'indie pop': 3}
# Artist name from filename: Incubus (band)
# Lookey here {'alternative rock': 5, 'alternative metal': 6, 'funk metal (early)': 0, 'nu metal (early)': 0}
# Artist name from filename: Interpol (band)
# Lookey here {'indie rock': 2, 'post-punk revival': 3}
# Artist name from filename: INXS
# Lookey here {'new wave music': 3, 'new wave': 8, 'pub rock (australia)': 0, 'pub rock': 6, 'dance-rock': 2, 'funk rock': 2, 'alternative rock': 2}
# Artist name from filename: Iron Maiden
# Lookey here {'heavy metal music': 4, 'heavy metal': 35}
# Artist name from filename: Jackson Browne
# Lookey here {'folk rock': 2, 'soft rock': 1, 'pop rock': 2, 'country rock': 2}
# Artist name from filename: Jack White
# Lookey here {'blues rock': 2, 'garage rock revival': 3, 'alternative rock': 2, 'punk blues': 3, 'folk music': 2, 'folk': 4, 'country music': 1, 'country': 4, 'experimental rock': 1}
# Artist name from filename: James Blunt
# Lookey here {'pop rock': 2, 'folk rock': 1, 'folk-pop': 1, 'folk pop': 1, 'soft rock': 2}
# Artist name from filename: James Taylor
# Lookey here {'soft rock': 4, 'folk music': 2, 'folk': 11}
# Artist name from filename: Jane's Addiction
# Lookey here {'alternative rock': 7, 'alternative metal': 5, 'funk metal': 3, 'psychedelic rock': 4}
# Artist name from filename: Janis Joplin
# Lookey here {'psychedelic rock': 4, 'blues rock': 2, 'soul music': 1, 'soul': 4, 'blues': 51}
# Artist name from filename: Jefferson Airplane
# Lookey here {'psychedelic rock': 5, 'acid rock': 4, 'folk rock': 3}
# Artist name from filename: Jefferson Starship
# Lookey here {}
# Artist name from filename: Jeff Buckley
# Lookey here {'alternative rock': 1, 'folk-rock': 3, 'blues': 5}
# Artist name from filename: Jerry Lee Lewis
# Lookey here {'rock and roll': 23, 'rockabilly': 11, 'country music': 23, 'country': 78, 'gospel music': 2, 'gospel': 16, 'honky-tonk#music': 1, 'honky-tonk': 3, 'blues': 10, 'boogie-woogie': 5}
# Artist name from filename: Jethro Tull (band)
# Lookey here {'progressive rock': 10, 'folk rock': 6, 'hard rock': 7, 'blues rock': 3}
# Artist name from filename: Jet (Australian band)
# Lookey here {}
# Artist name from filename: Jimi Hendrix
# Lookey here {'psychedelic music': 1, 'psychedelia': 1, 'blues': 34, 'rhythm and blues': 5, 'r&b': 14}
# Artist name from filename: Jimmy Eat World
# Lookey here {'alternative rock': 3, 'emo': 5, 'pop-punk': 7, 'power pop': 3, 'pop rock': 3}
# Artist name from filename: Jim Croce
# Lookey here {'folk music': 2, 'folk': 10, 'soft rock': 2}
# Artist name from filename: Joan Jett
# Lookey here {}
# Artist name from filename: Joe Cocker
# Lookey here {'blues': 6, 'blue-eyed soul': 1, 'pop music': 1, 'pop': 8}
# Artist name from filename: Joe Satriani
# Lookey here {'instrumental rock': 2, 'hard rock': 4, 'blues rock': 1}
# Artist name from filename: Joe Walsh
# Lookey here {'hard rock': 5, 'blues rock': 2, 'pop rock': 1, 'progressive rock': 1, 'country rock': 1}
# Artist name from filename: John Fogerty
# Lookey here {'roots rock': 1, 'rock and roll': 10, 'country rock': 2, 'nowrap': 3, 'heartland rock': 1}
# Artist name from filename: John Lennon
# Lookey here {'pop music': 1, 'pop': 9, 'experimental music': 2, 'experimental': 6}
# Artist name from filename: John Mayall
# Lookey here {'british blues': 15, 'blues rock': 3, 'jazz&nbsp': 1}
# Artist name from filename: John Mayall & the Bluesbreakers
# Lookey here {'british blues': 2, 'blues rock': 3}
# Artist name from filename: John Mayer
# Lookey here {'pop music': 4, 'pop': 47, 'blues': 15}
# Artist name from filename: John Mellencamp
# Lookey here {'heartland rock': 3, 'roots rock': 2, 'folk rock': 2}
# Artist name from filename: Journey (band)
# Lookey here {'arena rock': 3, 'hard rock': 2, 'soft rock': 2, 'progressive rock (early)': 0, 'jazz rock (early)': 0}
# Artist name from filename: Joy Division
# Lookey here {'post-punk': 6, 'punk rock': 3, 'new wave music': 1, 'new wave': 2, 'gothic rock': 6}
# Artist name from filename: Judas Priest
# Lookey here {'heavy metal music': 5, 'heavy metal': 50}
# Artist name from filename: Kaiser Chiefs
# Lookey here {'indie rock': 4, 'pop rock': 1, 'post-punk revival': 1, 'art punk': 1, 'power pop': 2, 'pop punk': 1, 'alternative rock': 1}
# Artist name from filename: Kaleo (band)
# Lookey here {'blues rock': 3, 'indie folk': 2, 'alternative rock': 2}
# Artist name from filename: Kansas (band)
# Lookey here {'progressive rock': 10, 'art rock': 2, 'hard rock': 3, 'arena rock': 1}
# Artist name from filename: Keane (band)
# Lookey here {'alternative rock': 4, 'post-britpop': 4, 'soft rock': 1}
# Artist name from filename: Kenny Loggins
# Lookey here {'pop music': 1, 'pop': 11, 'folk rock': 1, 'contemporary r&b': 1, 'r&b': 2, 'soul music': 1, 'soul': 2, 'soft rock': 3}
# Artist name from filename: Kid Rock
# Lookey here {'hip-hop': 21, 'country music': 11, 'country': 42, 'heavy metal music': 3, 'heavy metal': 5}
# Artist name from filename: Killswitch Engage
# Lookey here {'melodic metalcore': 2}
# Artist name from filename: Kings of Leon
# Lookey here {'alternative rock': 4, 'southern rock': 3, 'indie rock': 1, 'garage rock revival': 1}
# Artist name from filename: Kiss (band)
# Lookey here {'hard rock': 17, 'heavy metal music': 2, 'heavy metal': 7, 'shock rock': 4, 'glam rock': 5}
# Artist name from filename: Korn
# Lookey here {'nu metal': 18, 'alternative metal': 5}
# Artist name from filename: Lacuna Coil
# Lookey here {'gothic metal': 7, 'alternative metal': 4}
# Artist name from filename: Lamb of God (band)
# Lookey here {'groove metal': 4, 'metalcore': 4, 'thrash metal': 6, 'death metal (early)': 0}
# Artist name from filename: Led Zeppelin
# Lookey here {'class=nowraplinks': 1, 'hard rock': 12, 'blues rock': 2, 'folk rock': 3, 'heavy metal music': 5, 'heavy metal': 18}
# Artist name from filename: Lenny Kravitz
# Lookey here {'funk': 9, 'soul music': 2, 'soul': 9}
# Artist name from filename: Lifehouse (band)
# Lookey here {'alternative rock': 2, 'post-grunge': 2, 'pop rock': 2}
# Artist name from filename: Limp Bizkit
# Lookey here {'nu metal': 13, 'rap rock': 4, 'rap metal': 4}
# Artist name from filename: Linda Ronstadt
# Lookey here {'country music': 16, 'country': 89, 'pop music': 8, 'pop': 66}
# Artist name from filename: Linkin Park
# Lookey here {'alternative rock': 11, 'nu metal': 15, 'rap rock': 7, 'alternative metal': 6, 'electronic rock': 5, 'pop rock': 5}
# Artist name from filename: Little Richard
# Lookey here {'rock and roll': 62, 'rhythm and blues': 13, 'gospel music': 4, 'gospel': 24, 'soul music': 5, 'soul': 22}
# Artist name from filename: Little River Band
# Lookey here {'album-oriented rock': 1, 'aor': 1, 'pop rock': 1, 'soft rock': 5}
# Artist name from filename: Live (band)
# Lookey here {'alternative rock': 4, 'post-grunge': 3, 'hard rock': 4}
# Artist name from filename: Living Colour
# Lookey here {'hard rock': 12, 'funk metal': 4, 'alternative metal': 4}
# Artist name from filename: Lou Reed
# Lookey here {'art rock': 3, 'proto-punk': 1, 'glam rock': 4}
# Artist name from filename: Loverboy
# Lookey here {'arena rock': 4, 'hard rock': 3, 'pop rock': 2, 'new wave music': 2, 'new wave (early)': 0}
# Artist name from filename: Lynyrd Skynyrd
# Lookey here {'southern rock': 11, 'blues rock': 3, 'country rock': 1, 'hard rock': 2}
# Artist name from filename: Manfred Mann's Earth Band
# Lookey here {'progressive rock': 4, 'hard rock': 2, 'jazz rock': 1}
# Artist name from filename: Manfred Mann
# Lookey here {'beat music': 1, 'beat': 4, 'blues rock': 2, 'british rhythm and blues': 3, 'r&b': 3, 'psychedelic music': 1, 'psychedelia': 2, 'progressive rock': 0, 'hard rock': 0}
# Artist name from filename: Manfred Mann (musician)
# Lookey here {}
# Artist name from filename: Manfred Mann Chapter Three
# Lookey here {'jazz rock': 3}
# Artist name from filename: Marilyn Manson
# Lookey here {'industrial rock': 1, 'industrial metal': 3, 'gothic rock': 2, 'alternative metal': 2, 'shock rock': 2}
# Artist name from filename: Marilyn Manson (band)
# Lookey here {'industrial rock': 5, 'industrial metal': 5, 'gothic rock': 5, 'alternative metal': 3, 'shock rock': 8}
# Artist name from filename: Matchbox Twenty
# Lookey here {'alternative rock': 2, 'post-grunge': 2, 'pop rock': 3}
# Artist name from filename: Meat Loaf
# Lookey here {'hard rock': 3}
# Artist name from filename: Megadeth
# Lookey here {'thrash metalsfn': 0, 'phillips': 6, 'cogan': 6, 'speed metalsfn': 0, 'heavy metal music': 4, 'heavy metalsfn': 0}
# Artist name from filename: Melissa Etheridge
# Lookey here {'heartland rock': 1, 'roots rock': 1, 'folk rock': 1, 'blues rock': 1, 'country rock': 1}
# Artist name from filename: Men at Work
# Lookey here {'new wave music': 1, 'new wave': 3, 'pop rock': 2, 'reggae rock': 2}
# Artist name from filename: Metallica
# Lookey here {'heavy metal music': 4, 'heavy metal': 26, 'thrash metal': 13, 'speed metal': 4, 'hard rock': 11}
# Artist name from filename: Michael Martin Murphey
# Lookey here {'progressive country': 7, 'western music (north america)': 0, 'western': 43, 'cowboy music': 9, 'bluegrass music': 3, 'bluegrass': 13}
# Artist name from filename: Midnight Oil
# Lookey here {'alternative rock': 4, 'hard rock': 4, 'post-punk': 2, 'new wave music': 1, 'new wave': 3}
# Artist name from filename: Mike and the Mechanics
# Lookey here {'pop rock': 2}
# Artist name from filename: Mitch Ryder
# Lookey here {'rock and roll': 6, 'rhythm and blues': 2, 'blue-eyed soul': 2, 'frat rock': 1, 'hard rock': 1}
# Artist name from filename: Modest Mouse
# Lookey here {'indie rock': 5, 'alternative rock': 1, 'post punk revival': 1, 'punk rock': 2, 'emo (early)': 0}
# Artist name from filename: Montgomery Gentry
# Lookey here {'country music': 36, 'country': 103, 'southern rock': 5, 'country rock': 1}
# Artist name from filename: Morrissey
# Lookey here {'alternative rock': 4, 'indie pop': 4, 'indie rock': 6, 'jangle pop': 2}
# Skipping Motley Crue - not in original artist list
# Skipping Motorhead - not in original artist list
# Artist name from filename: Mudvayne
# Lookey here {'alternative metal': 4, 'nu metal': 3, 'progressive metal': 7, 'hard rock': 4}
# Artist name from filename: Mumford & Sons
# Lookey here {'folk rock': 6, 'alternative rock': 2, 'indie folk': 2, 'americana music': 4, 'americana': 6, 'country music': 2, 'country': 5, 'bluegrass music': 2, 'bluegrass': 6}
# Artist name from filename: Muse (band)
# Lookey here {'alternative rock': 6, 'progressive rock': 6, 'space rock': 3, 'hard rock': 5, 'art rock': 3, 'electronic rock': 4}
# Artist name from filename: My Chemical Romance
# Lookey here {'alternative rock': 9, 'emo': 66, 'pop-punk': 8, 'post-hardcore': 7, 'punk rock': 8, 'hard rock': 4}
# Artist name from filename: Neil Young
# Lookey here {'folk rock': 6, 'country rock': 5}
# Artist name from filename: New York Dolls
# Lookey here {'hard rock': 4, 'proto-punk': 2, 'glam rock': 7, 'glam punk': 3}
# Artist name from filename: Nickelback
# Lookey here {'post-grunge': 3, 'hard rock': 6, 'alternative rock': 2, 'alternative metal': 3, 'pop rock': 3}
# Artist name from filename: Nine Inch Nails
# Lookey here {'industrial rock': 5, 'industrial music': 5, 'industrial': 32, 'alternative rock': 5, 'electronic rock': 3, 'industrial metal': 4, 'ambient music': 3, 'ambient': 5}
# Artist name from filename: Nirvana (band)
# Lookey here {'grunge': 20, 'alternative rock': 12, 'punk rock': 7}
# Artist name from filename: No Doubt
# Lookey here {'ska punk': 5, 'pop rock': 5, 'new wave music': 5, 'new wave': 9, 'alternative rock': 5, 'pop-punk': 5, 'reggae': 12}
# Artist name from filename: Oasis (band)
# Lookey here {'britpop': 29}
# Artist name from filename: Our Lady Peace
# Lookey here {'alternative rock': 19, 'post-grunge': 3}
# Artist name from filename: Ozzy Osbourne
# Lookey here {'heavy metal music': 3, 'heavy metal': 16, 'hard rock': 7}
# Artist name from filename: P.O.D.
# Lookey here {'nu metal': 6, 'rap rock': 1, 'alternative metal': 4, 'hardcore punk (early)': 0}
# Artist name from filename: Panic! at the Disco
# Lookey here {'pop rock': 7, 'baroque pop': 4, 'electropop': 3, 'alternative rock': 7, 'emo': 13, 'pop-punk': 2}
# Artist name from filename: Pantera
# Lookey here {'groove metal': 12, 'thrash metal': 10, 'glam metal (early)': 0}
# Artist name from filename: Papa Roach
# Lookey here {'alternative rock': 3, 'nu metal': 13, 'alternative metal': 3, 'rap metal': 5, 'hard rock': 7}
# Artist name from filename: Paramore
# Lookey here {'pop-punk': 9, 'emo': 15, 'pop rock': 4, 'alternative rock': 6, 'power pop': 4, 'new wave music': 3, 'new wave': 8}
# Artist name from filename: Parliament-Funkadelic
# Lookey here {'funk': 86, 'psychedelic funk': 4, 'funk rock': 2, 'acid rock': 2, 'progressive soul': 2}
# Artist name from filename: Parliament (band)
# Lookey here {'funk': 24, 'contemporary r&b': 1, 'r&b': 7, 'psychedelic soul': 3}
# Artist name from filename: Pat Benatar
# Lookey here {'hard rock': 8, 'pop rock': 1}
# Artist name from filename: Paul McCartney
# Lookey here {'pop music': 3, 'pop': 22, 'classical music': 5, 'classical': 22, 'electronic music': 1, 'electronic': 4}
# Artist name from filename: Paul McCartney and Wings
# Lookey here {'soft rock': 3}
# Artist name from filename: Pearl Jam
# Lookey here {'alternative rock': 4, 'grunge': 17, 'hard rock': 5}
# Artist name from filename: Peter Frampton
# Lookey here {}
# Artist name from filename: Peter Gabriel
# Lookey here {'progressive rock': 6, 'art rock': 3, 'worldbeat': 3, 'progressive soul': 3}
# Artist name from filename: Phil Collins
# Lookey here {'pop music': 5, 'pop': 45, 'soft rock': 2, 'progressive rock': 7, 'art rock': 3}
# Artist name from filename: Pink Floyd
# Lookey here {'progressive rock': 6, 'art rock': 4, 'psychedelic rock': 4, 'space rock': 3, 'experimental rock': 3}
# Artist name from filename: Pixies (band)
# Lookey here {'alternative rock': 9, 'indie rock': 4, 'noise pop': 1, 'punk rock': 6, 'surf rock': 3}
# Artist name from filename: Poison (American band)
# Lookey here {}
# Artist name from filename: Pop Evil
# Lookey here {'hard rock': 3, 'alternative metal': 2, 'post-grunge': 2}
# Artist name from filename: Primus (band)
# Lookey here {'alternative metal': 5, 'funk metal': 7, 'experimental rock': 3, 'progressive rock': 6}
# Artist name from filename: Puddle of Mudd
# Lookey here {'post-grunge': 8, 'hard rock': 4, 'alternative rock': 3}
# Skipping Queensryche - not in original artist list
# Artist name from filename: Queens of the Stone Age
# Lookey here {'alternative rock': 3, 'stoner rock': 5, 'palm desert scene': 3, 'desert rock': 1, 'hard rock': 10, 'alternative metal': 3}
# Artist name from filename: Queen (band)
# Lookey here {'pop music': 3, 'pop': 32}
# Artist name from filename: Quiet Riot
# Lookey here {'heavy metal music': 4, 'heavy metal': 14, 'hard rock': 9, 'glam metal': 4}
# Artist name from filename: R.E.M.
# Lookey here {'alternative rock': 14, 'jangle pop': 4, 'folk rock': 4, 'college rock': 5, 'post-punk': 8}
# Artist name from filename: Radiohead
# Lookey here {'art rock': 3, 'alternative rock': 7, 'electronica': 2, 'experimental rock': 3}
# Artist name from filename: Rage Against the Machine
# Lookey here {'rap metal': 5, 'rap rock': 5, 'funk metal': 5, 'alternative metal': 7}
# Artist name from filename: Rainbow (rock band)
# Lookey here {}
# Artist name from filename: Rammstein
# Lookey here {'lang': 8, 'de': 78, 'neue deutsche härte': 6, 'italic=no': 4, 'industrial metal': 3}
# Artist name from filename: Ramones
# Lookey here {'punk rock': 19, 'pop-punk': 11}
# Artist name from filename: Ratt
# Lookey here {'glam metal': 7, 'heavy metal music': 4, 'heavy metal': 11, 'hard rock': 5}
# Artist name from filename: Red Hot Chili Peppers
# Lookey here {'funk rock': 4, 'alternative rock': 5, 'rap rock': 5, 'funk metal': 9}
# Artist name from filename: REO Speedwagon
# Lookey here {'arena rock': 2, 'pop rock': 2, 'hard rock': 4, 'album-oriented rock': 1, 'aor': 1, 'blues rock (early)': 0}
# Artist name from filename: Ringo Starr
# Lookey here {'pop music': 1, 'pop': 4}
# Artist name from filename: Rise Against
# Lookey here {'punk rock': 10, 'melodic hardcore': 8}
# Artist name from filename: Ritchie Valens
# Lookey here {'rock and roll': 10, 'chicano rock': 4}
# Artist name from filename: Robert Plant
# Lookey here {'blues': 17, 'folk music': 2, 'folk': 8, 'country music': 2, 'country': 10, 'hard rock': 5, 'heavy metal music': 2, 'heavy metal': 8}
# Artist name from filename: Rob Zombie
# Lookey here {'industrial metal': 2, 'shock rock': 4, 'groove metal': 1, 'alternative metal': 2, 'hard rock': 4, 'nu metal': 2}
# Artist name from filename: Rod Stewart
# Lookey here {'pop': 9, 'blue-eyed soul': 1, 'blues rock': 1, 'folk rock': 1, 'soft rock': 3, 'disco': 5, 'traditional pop': 3}
# Artist name from filename: Roxy Music
# Lookey here {'art rock': 7, 'glam rock': 7, 'pop rock': 2, 'sophisti-pop': 5}
# Artist name from filename: Royal Blood (band)
# Lookey here {'hard rock': 1, 'blues rock': 2, 'garage rock': 1, 'stoner rock': 2, 'alternative rock': 1}
# Artist name from filename: Roy Orbison
# Lookey here {'pop music': 3, 'pop': 14, 'country music': 7, 'country': 22, 'rock and roll': 14, 'rockabilly': 7}
# Artist name from filename: Run-DMC
# Lookey here {'hip-hop': 73, 'rap rock': 6}
# Artist name from filename: Rush (band)
# Lookey here {'progressive rock': 20, 'hard rock': 15, 'heavy metal music': 2, 'heavy metal': 11}
# Artist name from filename: Saliva (band)
# Lookey here {'nu metal': 3, 'post-grunge': 2, 'rap metal': 2, 'hard rock': 2}
# Artist name from filename: Sam Fender
# Lookey here {'indie rock': 7, 'pop rock': 4, 'heartland rock': 4}
# Artist name from filename: Santana (band)
# Lookey here {'latin rock': 4, 'blues rock': 2, 'psychedelic rock': 2, 'acid rock': 3, 'chicano rock': 1, 'jazz fusion': 3, 'yacht rock': 4}
# Artist name from filename: Saving Abel
# Lookey here {'hard rock': 1, 'post-grunge': 2, 'southern rock': 2}
# Artist name from filename: Scorpions (band)
# Lookey here {'hard rock': 14, 'heavy metal music': 3, 'heavy metal': 18}
# Artist name from filename: Seether
# Lookey here {'post-grunge': 3, 'hard rock': 7, 'alternative metal': 3, 'alternative rock': 3, 'nu metal (early)': 0}
# Artist name from filename: Sepultura
# Lookey here {}
# Artist name from filename: Sex Pistols
# Lookey here {'punk rock': 20}
# Artist name from filename: Shakin' Stevens
# Lookey here {'rockabilly': 2, 'british rock and roll': 2, 'rock and roll': 5}
# Artist name from filename: Sheryl Crow
# Lookey here {'country rock': 2, 'pop music': 2, 'pop': 21, 'folk music': 2, 'folk': 4, 'blues': 4, 'heartland rock': 1}
# Artist name from filename: Shinedown
# Lookey here {'hard rock': 8, 'alternative metal': 4, 'post-grunge': 4, 'alternative rock': 3, 'pop rock': 4}
# Artist name from filename: Silverchair
# Lookey here {'alternative rock': 4, 'grunge': 17, 'art rock': 4, 'post-grunge': 4}
# Artist name from filename: Simon & Garfunkel
# Lookey here {'folk rock': 6}
# Artist name from filename: Simple Minds
# Lookey here {'post-punk': 3, 'art rock': 3, 'synth-pop': 8}
# Artist name from filename: Simple Plan
# Lookey here {}
# Artist name from filename: Sixto Rodriguez
# Lookey here {'folk rock': 2, 'psychedelic folk': 1, 'psychedelic rock': 1}
# Artist name from filename: Skid Row (American band)
# Lookey here {}
# Artist name from filename: Skillet (band)
# Lookey here {'christian rock': 9, 'hard rock': 5, 'alternative rock': 5, 'alternative metal': 3, 'post-grunge': 3, 'nu metal': 3}
# Artist name from filename: Slade
# Lookey here {'glam rock hard rock': 0}
# Artist name from filename: Slayer
# Lookey here {'thrash metal': 17}
# Artist name from filename: Slipknot (band)
# Lookey here {'nu metal': 6, 'alternative metal': 3, 'groove metal': 5}
# Artist name from filename: Sly and the Family Stone
# Lookey here {'psychedelic soul': 9}
# Artist name from filename: Small Faces
# Lookey here {'rhythm and blues': 2, 'r&b': 2, 'beat music': 1, 'beat': 3, 'pop music': 2, 'pop': 11, 'psychedelia': 2, 'proto-punk': 3, 'progressive pop': 2}
# Artist name from filename: Smash Mouth
# Lookey here {'alternative rock': 3, 'power pop': 3, 'pop rock': 3, 'ska punk': 4}
# Artist name from filename: Smokie (band)
# Lookey here {'pop rock': 2, 'soft rock': 2, 'glam rock': 3}
# Artist name from filename: Snow Patrol
# Lookey here {'alternative rock': 3, 'power pop': 1, 'post-britpop': 3, 'indie rock': 3}
# Artist name from filename: Social Distortion
# Lookey here {'punk rock': 11, 'cowpunk': 7, 'rock and roll': 4, 'hardcore punk (early)': 0}
# Artist name from filename: Sonic Youth
# Lookey here {'noise rock': 7, 'alternative rock': 6, 'experimental rock': 3, 'indie rock': 8, 'post-punk': 5, 'no wave (early)': 0}
# Artist name from filename: Soundgarden
# Lookey here {'grunge': 40, 'heavy metal music': 2, 'heavy metal': 7, 'alternative metal': 4, 'alternative rock': 5}
# Artist name from filename: Staind
# Lookey here {'alternative metal': 4, 'post-grunge': 8, 'nu metal': 7, 'hard rock': 2}
# Artist name from filename: Starset
# Lookey here {}
# Artist name from filename: Starship (band)
# Lookey here {'arena rock': 2, 'pop rock': 2}
# Artist name from filename: Status Quo (band)
# Lookey here {'boogie rock': 2, 'hard rock': 3, 'psychedelic music': 2, 'psychedelia (early)': 0}
# Artist name from filename: Steely Dan
# Lookey here {'jazz rock': 1, 'yacht rock': 3, 'soft rock': 2, 'pop music': 1, 'pop': 6, 'jazz fusion': 2}
# Artist name from filename: Steppenwolf (band)
# Lookey here {'psychedelic rock': 1, 'blues rock': 3, 'acid rock': 3, 'hard rock': 3, 'heavy metal music': 2, 'heavy metal': 7, 'garage rock': 1}
# Artist name from filename: Steve Miller Band
# Lookey here {'blues rock': 2, 'pop rock': 2}
# Artist name from filename: Steve Vai
# Lookey here {'instrumental rock': 1, 'hard rock': 4, 'heavy metal music': 3, 'heavy metal': 5, 'progressive metal': 2}
# Artist name from filename: Steve Winwood
# Lookey here {'blue-eyed soul': 2, 'rhythm and blues': 3, 'r&b': 1, 'pop music': 3, 'pop': 14}
# Artist name from filename: Stevie Nicks
# Lookey here {'pop music': 1, 'pop': 18, 'folk music': 1, 'folk': 3}
# Artist name from filename: Stevie Ray Vaughan
# Lookey here {'texas blues': 4, 'blues rock': 6, 'electric blues': 4, 'rock and roll': 5}
# Artist name from filename: Sting (musician)
# Lookey here {}
# Artist name from filename: Stone Sour
# Lookey here {}
# Artist name from filename: Stone Temple Pilots
# Lookey here {'alternative rock': 3, 'grunge': 18, 'hard rock': 17, 'alternative metal': 4, 'psychedelic rock': 5}
# Artist name from filename: Styx (band)
# Lookey here {'progressive rock': 3, 'art rock': 2, 'arena rock': 2, 'pop rock': 3}
# Artist name from filename: Sublime (band)
# Lookey here {'ska punk': 4, 'reggae rock': 3}
# Artist name from filename: Sublime with Rome
# Lookey here {'reggae rock': 4, 'alternative rock': 3, 'hip hop music': 1, 'hip hop': 3, 'dub music': 1, 'dub': 11, 'ska punk': 1, 'punk rock': 3}
# Artist name from filename: Sum 41
# Lookey here {'pop-punk': 35, 'skate punk': 7, 'punk rock': 6, 'alternative metal': 6, 'melodic hardcore': 5, 'alternative rock': 4}
# Artist name from filename: Supertramp
# Lookey here {'progressive pop': 3, 'progressive rock': 5, 'soft rock': 3, 'pop music': 6, 'pop': 18}
# Artist name from filename: Survivor (band)
# Lookey here {'arena rock': 2, 'hard rock': 2}
# Artist name from filename: System of a Down
# Lookey here {'alternative metal': 4, 'nu metal': 3, 'hard rock': 10, 'progressive metal': 3}
# Artist name from filename: T. Rex (band)
# Lookey here {'glam rock': 15, 'pop music': 2, 'pop': 12, 'psychedelic folk (early)': 0}
# Artist name from filename: Talking Heads
# Lookey here {'new wave music': 3, 'new wave': 9, 'post-punk': 6, 'avant-funk': 1, 'art pop': 3, 'worldbeat': 3}
# Artist name from filename: Ted Nugent
# Lookey here {'hard rock': 6}
# Artist name from filename: Tenacious D
# Lookey here {'comedy rock': 6, 'acoustic rock': 1, 'hard rock': 3, 'heavy metal music': 1, 'heavy metal': 4}
# Artist name from filename: Ten Years After
# Lookey here {'blues rock': 4}
# Artist name from filename: Tesla (band)
# Lookey here {'hard rock': 7, 'blues rock': 2, 'glam metal': 5}
# Artist name from filename: Theory of a Deadman
# Lookey here {'post-grunge': 5, 'hard rock': 6, 'alternative rock': 3, 'alternative metal': 3, 'pop rock': 3}
# Artist name from filename: The Alan Parsons Project
# Lookey here {'progressive rock': 3, 'art rock': 2, 'progressive pop': 3, 'soft rock': 4}
# Artist name from filename: The All-American Rejects
# Lookey here {'pop-punk': 1, 'power pop': 2, 'pop rock': 1, 'emo pop': 1}
# Artist name from filename: The Allman Brothers Band
# Lookey here {'southern rock': 9, 'blues rock': 2, 'jazz rock': 1, 'jam band': 5}
# Artist name from filename: The Animals
# Lookey here {'blues rock': 2, 'british rhythm and blues': 3, 'r&b': 2, 'psychedelic rock': 1, 'progressive rock': 6, 'rock and roll': 11}
# Artist name from filename: The B-52's
# Lookey here {}
# Artist name from filename: The Band
# Lookey here {'roots rock': 4, 'americana (music)': 0, 'americana': 9, 'folk rock': 3, 'country rock': 5}
# Artist name from filename: The Bangles
# Lookey here {'pop rock': 5, 'power pop': 3, 'new wave music': 1, 'new wave': 2, 'paisley underground': 5}
# Artist name from filename: The Beach Boys
# Lookey here {'pop music': 6, 'pop': 51, 'surf music': 8, 'surf': 46, 'psychedelic music': 1, 'psychedelia': 2}
# Artist name from filename: The Beatles
# Lookey here {'pop music': 7, 'pop': 33, 'beat music': 4, 'beat': 12, 'psychedelic music': 4, 'psychedelia': 4}
# Artist name from filename: The Big Bopper
# Lookey here {'rock and roll': 3, 'rockabilly': 2, 'country music': 2, 'country': 11}
# Artist name from filename: The Black Crowes
# Lookey here {'southern rock': 3, 'blues rock': 3, 'hard rock': 5, 'roots rock': 2, 'jam band': 1}
# Artist name from filename: The Black Keys
# Lookey here {'garage rock': 4, 'blues rock': 5, 'punk blues': 2, 'indie rock': 3}
# Artist name from filename: The Boxtones
# Lookey here {}
# Artist name from filename: The Byrds
# Lookey here {'pop music': 4, 'pop': 21, 'folk rock': 19, 'psychedelic music': 1, 'psychedelia': 6, 'raga rock': 5, 'country rock': 20, 'jangle pop': 1}
# Artist name from filename: The Cab
# Lookey here {'alternative rock': 4, 'pop punk': 3, 'pop rock': 2, 'power pop': 2, 'emo pop': 2, 'pop music': 2, 'pop': 37}
# Artist name from filename: The Cardigans
# Lookey here {'alternative rock': 2, 'pop rock': 2, 'indie rock': 2, 'indie pop': 3}
# Artist name from filename: The Cars
# Lookey here {'new wave music': 3, 'new wave': 8, 'pop rock': 2, 'power pop': 5}
# Artist name from filename: The Clash
# Lookey here {'punk rock': 17, 'new wave music': 3, 'new wave': 8, 'post-punk': 3, 'reggae': 12, 'experimental rock': 4}
# Artist name from filename: The Cranberries
# Lookey here {'alternative rock': 7, 'indie rock': 4, 'pop rock': 3, 'jangle pop': 4, 'post-punk': 5, 'dream pop': 4}
# Artist name from filename: The Cult
# Lookey here {'hard rock': 10, 'gothic rock': 7, 'alternative rock': 3, 'heavy metal music': 2, 'heavy metal': 6, 'post-punk (early)': 0}
# Artist name from filename: The Cure
# Lookey here {'gothic rock': 6, 'post-punk': 7, 'alternative rock': 4, 'new wave music': 3, 'new wave': 8}
# Artist name from filename: The Dave Clark Five
# Lookey here {'rock and roll': 9, 'beat music': 1, 'beat': 4, 'pop music': 1, 'pop': 3}
# Artist name from filename: The Doobie Brothers
# Lookey here {'soft rock': 3, 'pop music': 1, 'pop': 6, 'blue-eyed&nbsp': 1, 'soul': 4}
# Artist name from filename: The Doors
# Lookey here {'psychedelic rocksfn': 0, 'debolt': 2, 'baugess': 2, '2011': 52, 'blues rocksfn': 0, 'wallace': 2, 'acid rocksfn': 0, 'einarson': 3}
# Artist name from filename: The Everly Brothers
# Lookey here {'rock and roll': 13, 'rockabilly': 4, 'country rock': 10, 'country music': 14, 'country': 42}
# Artist name from filename: The Fixx
# Lookey here {'new wave music': 1, 'new wave': 3, 'pop rock': 1, 'art rock': 1, 'dance-rock': 1}
# Artist name from filename: The Flaming Lips
# Lookey here {'neo-psychedelia': 2, 'experimental rock': 3, 'alternative rock': 4, 'indie rock': 2, 'psychedelic rock': 4}
# Artist name from filename: The Four Seasons (band)
# Lookey here {'pop rock': 2, 'pop music': 2, 'pop': 11, 'soul music': 1, 'soul': 10, 'doo-wop': 1}
# Artist name from filename: The Fray
# Lookey here {'alternative rock': 3, 'pop rock': 4, 'soft rock': 2, 'christian rock (early)': 0}
# Artist name from filename: The Go-Go's
# Lookey here {'new wave music': 2, 'new wave': 7, 'pop rock': 2, 'power pop': 3, 'post-punk': 1, 'punk rock (early)': 0}
# Artist name from filename: The Guess Who
# Lookey here {'hard rock': 3, 'psychedelic rock': 2, 'blues rock': 2, 'garage rock': 3}
# Artist name from filename: The Hives
# Lookey here {'garage rock revival': 2, 'garage punk (fusion genre)': 0, 'garage punk': 3}
# Artist name from filename: The Hollies
# Lookey here {'pop music': 4, 'pop': 10}
# Artist name from filename: The J. Geils Band
# Lookey here {'blues rock (early)': 0, 'new wave music': 2, 'new wave (later)': 0}
# Artist name from filename: The Jam
# Lookey here {'mod revival': 4, 'new wave music': 2, 'new wave': 9, 'punk rock': 4, 'power pop': 2}
# Artist name from filename: The Jesus and Mary Chain
# Lookey here {'alternative rock': 6, 'indie rock': 2, 'noise pop': 3, 'post-punk': 2, 'shoegaze': 7}
# Artist name from filename: The Killers
# Lookey here {'alternative rock': 4, 'indie rock': 5, 'post-punk revival': 3, 'new wave music': 2, 'new wave': 4, 'heartland rock': 3, 'pop rock': 2}
# Artist name from filename: The Kinks
# Lookey here {'pop music': 3, 'pop': 17}
# Artist name from filename: The Lovin' Spoonful
# Lookey here {'folk rock': 9, 'pop music': 3, 'pop': 22}
# Artist name from filename: The Lumineers
# Lookey here {'indie folk': 3, 'folk rock': 2, 'americana (music)': 0, 'americana': 11}
# Artist name from filename: The Mamas & the Papas
# Lookey here {'folk rock': 5, 'sunshine pop': 1}
# Artist name from filename: The Marshall Tucker Band
# Lookey here {'southern rock': 12, 'country rock': 4, 'progressive country': 5, 'blues rock': 3, 'jazz fusion': 1, 'jazz rock': 2}
# Artist name from filename: The Monkees
# Lookey here {'pop rock': 3, 'bubblegum music': 1, 'bubblegum': 5, 'psychedelic music': 2, 'psychedelia': 2}
# Artist name from filename: The Moody Blues
# Lookey here {'progressive rock': 6, 'art rock': 5, 'psychedelic rock': 4, 'pop rock': 1}
# Artist name from filename: The Mothers of Invention
# Lookey here {'jazz rock': 1, 'experimental rock': 2, 'progressive rock': 2, 'comedy rock': 2, 'blues rock': 2, 'avant-garde music': 1, 'avant-garde': 3, 'doo-wop': 4, 'art rock': 1}
# Artist name from filename: The Offspring
# Lookey here {}
# Artist name from filename: The Outfield
# Lookey here {'pop rock': 5, 'new wave music': 2, 'new wave': 5}
# Artist name from filename: The Police
# Lookey here {'new wave music': 4, 'new wave': 15, 'reggae rock': 3, 'post-punk': 2, 'pop rock': 2}
# Artist name from filename: The Presidents of the United States of America (band)
# Lookey here {'alternative rock': 4, 'pop-punk': 2, 'post-grunge': 3}
# Artist name from filename: The Pretenders
# Lookey here {'pop rock': 2, 'new wave music': 2, 'new wave': 5, 'alternative rock': 2}
# Artist name from filename: The Pretty Reckless
# Lookey here {'hard rock': 6, 'alternative rock': 3, 'post-grunge': 3, 'blues rock': 2}
# Artist name from filename: The Rolling Stones
# Lookey here {}
# Artist name from filename: The Script
# Lookey here {'pop rock': 3, 'soft rock': 2, 'indie rock': 1}
# Artist name from filename: The Smashing Pumpkins
# Lookey here {'alternative rock': 17}
# Artist name from filename: The Smiths
# Lookey here {'indie pop': 3, 'indie rock': 3, 'jangle pop': 3, 'alternative rock': 4}
# Artist name from filename: The Stone Roses
# Lookey here {'madchester': 4, 'indie rock': 2, 'alternative rock': 3, 'dance-rock': 3, 'neo-psychedelia': 2}
# Artist name from filename: The Strokes
# Lookey here {'indie rock': 6, 'garage rock revival': 4, 'post-punk revival': 5, 'new wave music': 2, 'new wave': 5, 'synth-pop': 2}
# Artist name from filename: The Sweet
# Lookey here {'glam rock': 7, 'hard rock': 14, 'power pop': 2, 'bubblegum music': 1, 'bubblegum (early)': 0}
# Artist name from filename: The Tragically Hip
# Lookey here {'alternative rock': 2, 'roots rock': 1, 'folk rock': 1}
# Artist name from filename: The Used
# Lookey here {'emo': 19, 'screamo': 5, 'post-hardcore': 5, 'pop-punk': 7, 'punk rock': 3, 'alternative rock': 3}
# Artist name from filename: The Velvet Underground
# Lookey here {'art rock': 2, 'proto-punk': 3, 'experimental rock': 2}
# Artist name from filename: The Verve
# Lookey here {'neo-psychedelia': 3, 'alternative rock': 6, 'britpop': 3, 'shoegaze (early)': 0}
# Artist name from filename: The White Stripes
# Lookey here {'garage rock': 16, 'blues rock': 5, 'alternative rock': 3, 'punk blues': 6, 'indie rock': 6}
# Artist name from filename: The Who
# Lookey here {'hard rock': 7, 'power pop': 4, 'proto-punk': 2}
# Artist name from filename: The Yardbirds
# Lookey here {'blues rock': 6, 'psychedelic rock': 7, 'british rhythm and blues': 3, 'r&b': 3}
# Artist name from filename: The Zombies
# Lookey here {'beat music': 1, 'beat': 6, 'baroque pop': 2, 'psychedelic pop': 2, 'r&b': 1, 'proto-prog': 2}
# Artist name from filename: Thin Lizzy
# Lookey here {'hard rock': 6, 'blues rock': 2, 'heavy metal music': 3, 'heavy metal': 11, 'folk rock (early)': 0}
# Artist name from filename: Third Eye Blind
# Lookey here {'alternative rock': 3, 'pop rock': 3, 'post-grunge': 2, 'power pop': 3, 'pop punk': 2}
# Artist name from filename: Thirty Seconds to Mars
# Lookey here {'alternative rock': 5}
# Artist name from filename: Thousand Foot Krutch
# Lookey here {'christian rock': 4, 'christian metal': 4, 'heavy metal music': 1, 'heavy metal': 2, 'hard rock': 8, 'alternative rock': 1, 'nu metal': 4, 'rap metal': 2}
# Artist name from filename: Three Days Grace
# Lookey here {'post-grunge': 9, 'hard rock': 17, 'alternative rock': 3, 'alternative metal': 8, 'nu metal': 4}
# Artist name from filename: Three Dog Night
# Lookey here {'pop rock': 2, 'soft rock': 2, 'roots rock': 1, 'funk rock': 1}
# Artist name from filename: Tommy James and the Shondells
# Lookey here {'bubblegum music': 3, 'bubblegum': 9}
# Artist name from filename: Tom Petty
# Lookey here {}
# Artist name from filename: Tom Petty and the Heartbreakers
# Lookey here {'heartland rock': 3, 'southern rock': 3}
# Artist name from filename: Tool (band)
# Lookey here {'alternative metal': 6, 'art rock': 5, 'post-metal': 7, 'progressive metal': 3, 'progressive rock': 7}
# Artist name from filename: Toto (band)
# Lookey here {'arena rock': 2, 'pop rock': 2, 'hard rock': 3, 'jazz fusion': 2, 'progressive rock': 2}
# Artist name from filename: Tracy Chapman
# Lookey here {'folk music': 1, 'folk': 15, 'blues rock': 2, 'pop music': 2, 'pop': 16, 'soul music': 1, 'soul': 4}
# Artist name from filename: Traffic (band)
# Lookey here {'progressive rock': 3, 'psychedelic rock': 3, 'jazz rock': 1, 'folk rock': 1, 'psychedelic pop (early)': 0}
# Artist name from filename: Train (band)
# Lookey here {'alternative rock': 2, 'pop rock': 3, 'roots rock': 2}
# Artist name from filename: Traveling Wilburys
# Lookey here {}
# Artist name from filename: Travis (band)
# Lookey here {'post-britpop': 2, 'pop rock': 1, 'alternative rock': 2}
# Artist name from filename: Trivium (band)
# Lookey here {'heavy metal music': 3, 'heavy metal': 13, 'thrash metal': 6, 'metalcore': 13, 'progressive metal': 2}
# Artist name from filename: Twenty One Pilots
# Lookey here {'alternative rock': 7, 'electropop': 5, 'alternative hip-hop': 4, 'pop rap': 3, 'indie pop': 4, 'pop rock': 3}
# Artist name from filename: Twisted Sister
# Lookey here {'heavy metal music': 4, 'heavy metal': 16, 'glam metal': 8, 'hard rock': 5, 'shock rock': 2}
# Artist name from filename: U2
# Lookey here {'alternative rock': 8, 'pop rock': 2, 'post-punk': 5}
# Artist name from filename: UB40
# Lookey here {'reggae': 35, 'dub music': 2, 'dub': 8}
# Artist name from filename: Uriah Heep (band)
# Lookey here {'hard rock': 8, 'progressive rock': 7, 'heavy metal music': 3, 'heavy metal': 14}
# Artist name from filename: Vampire Weekend
# Lookey here {'indie rock': 4, 'indie pop': 3, 'art pop': 1, 'baroque pop': 1, 'worldbeat': 1}
# Artist name from filename: Van Halen
# Lookey here {'hard rock': 12, 'heavy metal music': 2, 'heavy metal': 7, 'pop rock': 2, 'arena rock': 2, 'glam metal': 2}
# Artist name from filename: Van Morrison
# Lookey here {'blue-eyed soul': 3, 'celtic music': 3, 'celtic': 13, 'rhythm and blues': 8, 'r&b': 8, 'folk music': 9, 'folk': 19, 'blues': 26, 'jazz': 21, 'country music': 6, 'country': 22, 'gospel music': 4, 'gospel': 8, 'christian music': 1, 'christian': 3}
# Artist name from filename: Van Zant (band)
# Lookey here {}
# Artist name from filename: Velvet Revolver
# Lookey here {'hard rock': 13, 'alternative metal': 2}
# Artist name from filename: Volbeat
# Lookey here {'heavy metal music': 3, 'heavy metal': 9, 'hard rock': 7, 'rockabilly': 6, 'psychobilly': 3, 'groove metal': 3, 'rock and roll': 3}
# Artist name from filename: W.A.S.P. (band)
# Lookey here {'heavy metal music': 2, 'heavy metal': 8, 'shock rock': 2}
# Artist name from filename: Warrant (American band)
# Lookey here {}
# Artist name from filename: Weezer
# Lookey here {'alternative rock': 7, 'power pop': 6, 'pop rock': 2, 'geek rock': 7, 'pop-punk': 2, 'emo': 26}
# Artist name from filename: Whitesnake
# Lookey here {'hard rock': 20, 'blues rock': 4, 'glam metal': 6}
# Artist name from filename: White Zombie (band)
# Lookey here {'groove metal': 4, 'industrial metal': 4, 'alternative metal': 4, 'noise rock (early)': 0}
# Artist name from filename: X (American band)
# Lookey here {}
# Artist name from filename: X Ambassadors
# Lookey here {'alternative rock': 6, 'indie rock': 3, 'indie pop': 1, 'pop rock': 3, 'alternative pop': 2}
# Artist name from filename: Yes (band)
# Lookey here {'progressive rock': 17, 'art rock': 4, 'symphonic rock': 3, 'pop rock': 2}
# Artist name from filename: ZZ Top
# Lookey here {'blues rock': 3, 'hard rock': 4, 'boogie rock': 2, 'southern rock': 4}

# %%
# Basic network statistics
print(f"Number of nodes: {G.number_of_nodes()}")
print(f"Number of edges: {G.number_of_edges()}")
print(f"Network density: {nx.density(G):.4f}")
# print some names of nodes
print("Some node names:")
print(list(G.nodes())[:10])  # Print the first 10 node names
# Out:
# Number of nodes: 488
# Number of edges: 7197
# Network density: 0.0303
# Some node names:
# ['10cc', 'The Clash', 'George Harrison', 'Duran Duran', 'Toto (band)', 'Ringo Starr', 'Steely Dan', 'Roxy Music', 'The Yardbirds', 'Frank Zappa']

# %%
degrees = [G.degree(n) for n in G.nodes()]
print(f"Average degree: {sum(degrees)/len(degrees):.2f}")
print(f"Max degree: {max(degrees)}")
print(f"Min degree: {min(degrees)}")
# Out:
# Average degree: 29.50
# Max degree: 147
# Min degree: 0

# %%
# Remove nodes with degree 0 (isolated nodes)
print(f"Original graph: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges")

# Find nodes with degree 0
isolated_nodes = [node for node in G.nodes() if G.degree(node) == 0]
print(f"Found {len(isolated_nodes)} isolated nodes (degree 0)")

if isolated_nodes:
    print(f"Example isolated nodes: {isolated_nodes[:10]}")

# Remove isolated nodes
G.remove_nodes_from(isolated_nodes)

print(f"After removing isolated nodes: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges")

#Alternative: Create a new graph without isolated nodes
G_connected = G.copy()
G_connected.remove_nodes_from([node for node in G_connected.nodes() if G_connected.degree(node) == 0])

# Update the saved network
with open('rock_artists_network.pkl', 'wb') as f:
    pickle.dump(G_connected, f)
    
print("Updated network saved (without isolated nodes)")
# Out:
# Original graph: 488 nodes, 7197 edges
# Found 4 isolated nodes (degree 0)
# Example isolated nodes: ['Dr. Hook & the Medicine Show', 'Jet (Australian band)', "The B-52's", 'Van Zant (band)']
# After removing isolated nodes: 484 nodes, 7197 edges
# Updated network saved (without isolated nodes)

# %%
# Extract the largest weakly connected component
weakly_connected_components = list(nx.weakly_connected_components(G))
print(f"Number of weakly connected components: {len(weakly_connected_components)}")

# Find the largest component (by number of nodes)
component_sizes = [len(component) for component in weakly_connected_components]
print(f"Component sizes: {sorted(component_sizes, reverse=True)}")

# Get the largest component
largest_component_nodes = max(weakly_connected_components, key=len)
print(f"Largest component has {len(largest_component_nodes)} nodes")

# Create a subgraph containing only the largest component
largest_component = G.subgraph(largest_component_nodes).copy()

print(f"\nLargest component statistics:")
print(f"Number of nodes: {largest_component.number_of_nodes()}")
print(f"Number of edges: {largest_component.number_of_edges()}")
print(f"Network density: {nx.density(largest_component):.4f}")

# Show some example nodes from the largest component
print(f"\nSample nodes from largest component: {list(largest_component_nodes)[:10]}")

# Save the largest component as a separate graph
with open('largest_component.pkl', 'wb') as f:
    pickle.dump(largest_component, f)
    
print("\nLargest component saved as 'largest_component.pkl'")
# Out:
# Number of weakly connected components: 1
# Component sizes: [484]
# Largest component has 484 nodes
#
# Largest component statistics:
# Number of nodes: 484
# Number of edges: 7197
# Network density: 0.0308
#
# Sample nodes from largest component: ['10cc', 'Journey (band)', 'New York Dolls', 'George Harrison', 'AC/DC', 'Duran Duran', 'Toto (band)', 'Third Eye Blind', 'Alice Cooper (band)', 'The Used']
#
# Largest component saved as 'largest_component.pkl'
